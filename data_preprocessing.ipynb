# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 19.4 MB 39.3 MB/s
# ...
#      |████████████████████████████████| 453 kB 47.1 MB/s
# ...

# %%
import pandas as pd
import numpy as np
from konlpy.tag import Mecab
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
df = pd.read_csv('/content/drive/MyDrive/KHUDA/1기/동아리 연합공모전/data/2022_ESG.csv')
df_industry = pd.read_csv('/content/drive/MyDrive/KHUDA/1기/동아리 연합공모전/data/index_to_company.csv', encoding = 'cp949')

# %%
df_industry
# Out:
#     주식코드             인덱스 종류  \
# 0   1001                코스피
# 1   1002            코스피 대형주
# 2   1003            코스피 중형주
# 3   1004            코스피 소형주
# 4   1005               음식료품
# 5   1006               섬유의복
# 6   1007               종이목재
# 7   1008                 화학
# 8   1009                의약품
# 9   1010              비금속광물
# 10  1011               철강금속
# 11  1012                 기계
# 12  1013               전기전자
# 13  1014               의료정밀
# 14  1015               운수장비
# 15  1016                유통업
# 16  1017              전기가스업
# 17  1018                건설업
# 18  1019              운수창고업
# 19  1020                통신업
# 20  1021                금융업
# 21  1022                 은행
# 22  1024                 증권
# 23  1025                 보험
# 24  1026               서비스업
# 25  1027                제조업
# 26  1028            코스피 200
# 27  1034            코스피 100
# 28  1035             코스피 50
# 29  1150  코스피 200 커뮤니케이션서비스
# 30  1151         코스피 200 건설
# 31  1152        코스피 200 중공업
# ...

# %%
df_industry_selected = df_industry[['인덱스 종류', '회사이름']]

# %%
df_industry_selected
# Out:
#                인덱스 종류                                               회사이름
# 0                 코스피  ['삼성전자', 'LG에너지솔루션', 'SK하이닉스', 'NAVER', '삼성바이오...
# 1             코스피 대형주  ['삼성전자', 'SK하이닉스', 'NAVER', '삼성바이오로직스', '카카오',...
# 2             코스피 중형주  ['메리츠금융지주', '메리츠화재', '한전기술', '한화시스템', 'DB하이텍',...
# 3             코스피 소형주  ['일동제약', 'F&F홀딩스', '흥아해운', '디티알오토모티브', '코리아써키트...
# 4                음식료품  ['CJ제일제당', '오리온', '하이트진로', '농심', '오뚜기', '롯데칠성'...
# 5                섬유의복  ['F&F', '한세실업', '한섬', 'LF', 'BYC', '대한방직', '일신...
# 6                종이목재  ['아세아제지', '신대양제지', '한솔제지', '태림포장', '무림P&P', '대...
# 7                  화학  ['LG화학', 'SK이노베이션', 'LG생활건강', '아모레퍼시픽', 'S-Oil...
# 8                 의약품  ['삼성바이오로직스', '셀트리온', 'SK바이오사이언스', '유한양행', '한미약...
# 9               비금속광물  ['포스코케미칼', '쌍용C&E', '아이에스동서', '한일시멘트', 'KCC글라스...
# 10               철강금속  ['POSCO', '고려아연', '현대제철', '동국제강', '영풍', 'KG동부제...
# 11                 기계  ['두산중공업', '한온시스템', '두산밥캣', '씨에스윈드', '한미반도체', '...
# ...

# %%
df = df.dropna()

# %%
df[['기업명 (코드)']].iloc[0]
# Out:
# 기업명 (코드)    한샘 (009240)
# Name: 0, dtype: object

# %%
df_industry_selected[['회사이름']].iloc[0]
# Out:
# 회사이름    ['삼성전자', 'LG에너지솔루션', 'SK하이닉스', 'NAVER', '삼성바이오...
# Name: 0, dtype: object

# %%
df
# Out:
#           기업명 (코드)                                        Environment  \
# 0      한샘 (009240)                                               환경경영
# 1   금호타이어 (073240)                    기후변화 대응, 친환경 사업장 구축, 친환경 타이어 확대
# 2     락앤락 (115390)                                  탄소중립을 향한 에너지경영 실천
# 3    대한유화 (006650)                          친환경 사업 포트폴리오 관리, 환경경영 고도화
# 4   롯데칠성음료 (005300  기후변화 위험 및 기회, 환경경영체계 및 탄소중립, 기후변화 대응, 수자원 관리, ...
# ..             ...                                                ...
# 68  현대모비스 (012330)                             환경경영, 기후변화 대응, 순환경제 구현
# 69  SK렌터카 (068400)                                      기후위기 대응, 녹색경영
# 70    OCI (010060)                                      기후위기 대응, 환경경영
# 71    카카오 (035720)        환경경영체계, 기후변화대응, 친환경 데이터센터, 환경영향 저감, 친환경 서비스
# 72   롯데제과 (280360)                     환경경영체계, 순환경제, 기후변화 대응, 친환경 사업장
#
#                                               Society  \
# 0                  고객감동 경영, 인재경영, 안전경영, 상생경영, 지역사회 참여
# ...

# %%
df_industry_selected[['회사이름']].iloc[0][0]
# Out:
# "['삼성전자', 'LG에너지솔루션', 'SK하이닉스', 'NAVER', '삼성바이오로직스', '카카오', 'LG화학', '현대차', '삼성SDI', '기아', 'POSCO', 'KB금융', '셀트리온', '카카오뱅크', '현대모비스', '삼성물산', 'LG전자', '신한지주', 'SK이노베이션', '카카오페이', 'HMM', 'SK', '한국전력', 'LG생활건강', '하나금융지주', '크래프톤', '두산중공업', '삼성전기', 'SK텔레콤', '삼성생명', 'LG', '하이브', 'KT&G', 'SK바이오사이언스', '삼성에스디에스', '고려아연', '아모레퍼시픽', '우리금융지주', 'S-Oil', '현대중공업', '대한항공', '엔씨소프트', '삼성화재', '포스코케미칼', 'SK아이이테크놀로지', '넷마블', 'KT', 'LG이노텍', '기업은행', 'SK스퀘어', '롯데케미칼', '한화솔루션', 'SK바이오팜', 'F&F', '한국조선해양', '현대글로비스', 'LG디스플레이', '한온시스템', '에스디바이오센서', '강원랜드', 'LG유플러스', 'CJ제일제당', '현대제철', '맥쿼리인프라', '삼성중공업', '미래에셋증권', 'SKC', '현대건설', '코웨이', '삼성엔지니어링', '금호석유', '메리츠화재', '메리츠금융지주', '한국타이어앤테크놀로지', '현대중공업지주', '유한양행', '한국금융지주', '한국가스공사', '일진머티리얼즈', '메리츠증권', 'DB손해보험', '두산밥캣', 'GS', 'GS건설', '쌍용C&E', '아모레G', '이마트', '삼성증권', '한국항공우주', '삼성카드', '팬오션', '한진칼', 'NH투자증권', '한전기술', '오리온', '현대미포조선', '한미약품', '한화시스템', '현대오토에버', 'CJ대한통운', '한미사이언스', '롯데지주', '호텔신라', 'DB하이텍', 'BGF리테일', '한화에어로스페이스', '대우조선해양', '대우건설', 'KCC', 'GS리테일', '씨에스윈드', '에스
# ...

# %%
if df[['기업명 (코드)']].iloc[0][0].split()[0] in df_industry_selected[['회사이름']].iloc[0][0]:
    print('good')
# Out:
# good

# %%
del df_industry_selected['']

# %%
data = {}

# %%
df_industry_selected['G'] = ''

# %%
df_industry_selected
# Out:
#                인덱스 종류                                               회사이름 E S G
# 0                 코스피  ['삼성전자', 'LG에너지솔루션', 'SK하이닉스', 'NAVER', '삼성바이오...
# 1             코스피 대형주  ['삼성전자', 'SK하이닉스', 'NAVER', '삼성바이오로직스', '카카오',...
# 2             코스피 중형주  ['메리츠금융지주', '메리츠화재', '한전기술', '한화시스템', 'DB하이텍',...
# 3             코스피 소형주  ['일동제약', 'F&F홀딩스', '흥아해운', '디티알오토모티브', '코리아써키트...
# 4                음식료품  ['CJ제일제당', '오리온', '하이트진로', '농심', '오뚜기', '롯데칠성'...
# 5                섬유의복  ['F&F', '한세실업', '한섬', 'LF', 'BYC', '대한방직', '일신...
# 6                종이목재  ['아세아제지', '신대양제지', '한솔제지', '태림포장', '무림P&P', '대...
# 7                  화학  ['LG화학', 'SK이노베이션', 'LG생활건강', '아모레퍼시픽', 'S-Oil...
# 8                 의약품  ['삼성바이오로직스', '셀트리온', 'SK바이오사이언스', '유한양행', '한미약...
# 9               비금속광물  ['포스코케미칼', '쌍용C&E', '아이에스동서', '한일시멘트', 'KCC글라스...
# 10               철강금속  ['POSCO', '고려아연', '현대제철', '동국제강', '영풍', 'KG동부제...
# 11                 기계  ['두산중공업', '한온시스템', '두산밥캣', '씨에스윈드', '한미반도체', '...
# ...

# %%
df_industry_selected[['E']].iloc[1][0]
# Out:
# ''

# %%
df_industry_selected[['E']].iloc[1][0] = df_industry_selected[['E']].iloc[1][0]+(df[['Environment']].iloc[1][0])

# %%
df_industry_selected[['E']].iloc[1][0]
# Out:
# ''

# %%
i = 0

while i != 67:
    k = 0
    while k != 47:
        if df[['기업명 (코드)']].iloc[i][0].split()[0] in df_industry_selected[['회사이름']].iloc[k][0]:
            df_industry_selected.loc[i, 'E'] = df_industry_selected[['E']].iloc[k][0]+(df[['Environment']].iloc[i][0])
            df_industry_selected.loc[i, 'S'] = df_industry_selected[['S']].iloc[k][0]+(df[['Society']].iloc[i][0])
            df_industry_selected.loc[i, 'G'] = df_industry_selected[['G']].iloc[k][0]+(df[['Governance']].iloc[i][0])

            k += 1
        else:
            k += 1
    i += 1

# %%
df_industry_selected
# Out:
#      인덱스 종류                                               회사이름  \
# 0       코스피  ['삼성전자', 'LG에너지솔루션', 'SK하이닉스', 'NAVER', '삼성바이오...
# 1   코스피 대형주  ['삼성전자', 'SK하이닉스', 'NAVER', '삼성바이오로직스', '카카오',...
# 2   코스피 중형주  ['메리츠금융지주', '메리츠화재', '한전기술', '한화시스템', 'DB하이텍',...
# 3   코스피 소형주  ['일동제약', 'F&F홀딩스', '흥아해운', '디티알오토모티브', '코리아써키트...
# 4      음식료품  ['CJ제일제당', '오리온', '하이트진로', '농심', '오뚜기', '롯데칠성'...
# ..      ...                                                ...
# 62      NaN                                                NaN
# 63      NaN                                                NaN
# 64      NaN                                                NaN
# 65      NaN                                                NaN
# 66      NaN                                                NaN
#
#                                                     E  \
# 0                                                환경경영
# 1                     기후변화 대응, 친환경 사업장 구축, 친환경 타이어 확대
# ...

# %%
type(df_name.iloc[0][0])
# Out:
# str

# %%
df_name.iloc[0][0].split()[0]
# Out:
# '한샘'

# %%
name_list

# %%
name_df = pd.DataFrame(name_list, columns = ['기업명'])

# %%
df_E = df[['Environment']]
df_S = df[['Society']]
df_G = df[['Governance']]

# %%
df_E.iloc[0][0]
# Out:
# '환경경영'

# %%
all_E
# ','기준 띄어쓰기, 빈도수 산출, G에 해당하지 않는 단어 삭제

# %%
all_sentence1 = ", ".join(all_E)
all_sentence2 = ", ".join(all_S)
all_sentence3 = ", ".join(all_G)

# %%
all_sentence1 = all_sentence1.split('/')
all_sentence2 = all_sentence2.split('/')
all_sentence3 = all_sentence3.split('/')

# %%
all_sentence1 = ", ".join([str(_) for _ in all_sentence1])
all_sentence2 = ", ".join([str(_) for _ in all_sentence2])
all_sentence3 = ", ".join([str(_) for _ in all_sentence3])

# %%
all_sentence1 = all_sentence1.split('-')
all_sentence2 = all_sentence2.split('-')
all_sentence3 = all_sentence3.split('-')

# %%
all_sentence1 = ", ".join([str(_) for _ in all_sentence1])
all_sentence2 = ", ".join([str(_) for _ in all_sentence2])
all_sentence3 = ", ".join([str(_) for _ in all_sentence3])

# %%
all_sentence1 = all_sentence1.split('·')
all_sentence2 = all_sentence2.split('·')
all_sentence3 = all_sentence3.split('·')

# %%
all_sentence1 = ", ".join([str(_) for _ in all_sentence1])
all_sentence2 = ", ".join([str(_) for _ in all_sentence2])
all_sentence3 = ", ".join([str(_) for _ in all_sentence3])

# %%
all_sentence1
# Out:
# ['환경경영',
#  '기후변화 대응',
#  '친환경 사업장 구축',
#  '친환경 타이어 확대',
#  '탄소중립을 향한 에너지 경영 실천',
#  '친환경 사업 포트폴리오 관리',
#  '환경경영 고도화',
#  '기후변화 위험 및 기회',
#  '환경경영 체계 및 탄소중립',
#  '기후변화 대응',
#  '수자원 관리',
#  '자원순환 경제 구축',
#  '기후변화 대응',
#  '환경영향 최소화',
#  '환경 관리 고도화',
#  '환경경영',
#  '기술 개발 혁신',
#  '기후변화 대응',
#  '신재생에너지',
#  '친환경 경영',
#  '기후 위기 대응',
#  '환경영향 저감',
#  '기후변화 대응 SBTi 수립',
#  '지속 가능 금융 프레임워크 제정',
#  '환경정책',
#  '전략',
#  '기후변화 대응',
#  '환경영향 저감',
#  '친환경 물류 서비스 운영',
#  '물류',
#  '운송에너지 효율화',
#  '생물 다양성 보전',
#  '환경경영 성과',
#  '환경경영',
#  '환경 관리',
#  '기후변화 대응',
#  '그린경영',
#  '기후변화 대응',
#  '오염 및 유해 물질 관리,수자원 관리',
#  '폐기물 배출 및 관리',
#  '친환경 제품 개발 및 인증 확대',
#  '환경경영 체계',
#  '환경 데이터',
#  '친환경 경영',
#  '친환경 시스템',
#  '기후변화 대응',
#  '산림과 목재',
#  '친환경 경영',
#  '친환경 시스템',
#  '기후변화 대응',
#  '산림과 목재',
#  '기후변화 대응',
#  '그린경영',
#  '기후변화 대응',
#  '그린경영',
#  '기후변화 대응',
#  '그린경영',
#  '기후변화 대응',
#  '그린경영',
#  '기후변화 대응',
#  '환경 효율성 관리',
#  '탄소중립',
#  '자원순환',
#  '제품 전과정 책임',
#  'For the Planet',
#  '환경경영',
# ...

# %%
all_sentence1 = '환경경영, 기후변화 대응, 친환경 사업장 구축, 친환경 타이어 확대, 탄소중립을 향한 에너지 경영 실천, 친환경 사업 포트폴리오 관리, 환경경영 고도화, 기후변화 위험 및 기회, 환경경영 체계 및 탄소중립, 기후변화 대응, 수자원 관리, 자원순환 경제 구축, 기후변화 대응, 환경영향 최소화, 환경 관리 고도화, 환경경영, 기술 개발 혁신, 기후변화 대응, 신재생에너지, 친환경 경영, 기후 위기 대응, 환경영향 저감, 기후변화 대응 SBTi 수립, 지속 가능 금융 프레임워크 제정, 환경정책, 전략, 기후변화 대응, 환경영향 저감, 친환경 물류 서비스 운영, 물류, 운송에너지 효율화, 생물 다양성 보전, 환경경영 성과, 환경경영, 환경 관리, 기후변화 대응, 그린경영, 기후변화 대응, 오염 및 유해 물질 관리,수자원 관리, 폐기물 배출 및 관리, 친환경 제품 개발 및 인증 확대, 환경경영 체계, 환경 데이터, 친환경 경영, 친환경 시스템, 기후변화 대응, 산림과 목재, 친환경 경영, 친환경 시스템, 기후변화 대응, 산림과 목재, 기후변화 대응, 그린경영, 기후변화 대응, 그린경영, 기후변화 대응, 그린경영, 기후변화 대응, 그린경영, 기후변화 대응, 환경 효율성 관리, 탄소중립, 자원순환, 제품 전과정 책임, For the Planet, 환경경영, 기후변화 대응(TCFD Report), 환경을 위한 기후변화 전략 고도화, 녹색경영, 녹색금융 확대, 기후변화 대응, 친환경 조성, 기후변화 대응, 친환경 경영, 기후변화 대응과 순환 경제체계 구축, 기후변화 대응과 순환 경제체계 구축, 기후변화 대응과 순환 경제체계 구축, 녹색금융 추진, 친환경 경영 실천, 환경 관리, 환경경영, 친환경 연구개발, 친환경 책임 투자 확대, 탈탄소 및 기후리스크 관리, 금융자산의 탄소 배출량 측정 시스템, 기후 채권, 녹색 채권, 환경보호와 친환경 경영 내재화, 기후변화 대응 노력, 환경영향 최소화, 환경경영, 기후변화 대응, 제품 모든 과정 환경영향 저감, 에너지와 물, 자원순환과 자연보호, 환경경영, TCFD Report, 환경영향 저감, 환경 경영, 기후변화, 친환경 사업장, 친환경 제품, 기후변화 대응, TCFD Report, 환경안전·보건 경영, 환경경영, 기후변화 대응, 순환 경제, 유해 물질 관리 강화, 기후변화 대응, 녹색경영, 환경경영시스템, 기후변화 대응, 원재료 조달 관리 및 자원순환, 환경경영, 기후변화 대응, 환경경영관리 체계, Green Product, 환경경영, 기후변화 대응, 친환경 중심 포트폴리오 구축, 탄소중립 & 친환경 조선소 구축, 환경경영 강화, 기후 위기 대응, 환경영향 최소화, 환경경영 추진체계, 기후 행동, 자원순환 극대화, 환경친화적인 공급망, 환경경영, 안전보건 경영, 친환경 경영 선도, 저탄소 경영 추진, 기후변화 리스크 대응, Value Chain 내 온실가스 관리, 친환경 데이터 센터 운영, 친환경 물류체계 구축, 환경경영, 기후변화 대응, 환경 영향 저감, 안전·보건·환경 경영, 사업장 탄소중립 및 제품 탄소 배출 감축 전략, 환경경영, 기후변화 대응, 환경경영, 사업장 에너지 및 탄소 배출, 환경자원 관리, 환경경영, 환경영향 관리, 기후변화 완화, 기후변화 대응 전략 수립 및 리스크 관리(TCFD), 환경경영, 자원성 순환 체계 구축, 기후변화 대응, 친환경 경영, 기후변화, 자원순환, 환경경영, 기후변화 대응, 순환 경제 구현, 기후 위기 대응, 녹색경영, 기후 위기 대응, 환경경영, 환경경영 체계, 기후변화 대응, 친환경 데이터 센터, 환경영향 저감, 친환경 서비스, 환경경영 체계, 순환 경제, 기후변화 대응, 친환경 사업장'

# %%
all_sentence2 = '고객 감동 경영, 인재경영, 안전 경영, 상생 경영, 지역사회 참여, 행복한 일터 인재경영, 인권 경영, 조직문화, 안전한 사업장 안전보건 고도화, 화학물질 관리, 포용적 상생 협력 지속 가능한 공급망, 사회 공헌, 지구와 사람을 위한 안전한 제품 생산, 안전보건 리스크 관리, 공급망 책임 관리, 고객의 건강과 영양, 제품 안전 및 품질, 지속 가능한 공급망 관리, 동반성장을 위한 상생 프로그램, 인권 경영, 인재경영, 직원 가치 증대, 사회 공헌, 산업안전 강화, 미래가치 창출, 안전보건 경영, 협력사 상생발전, 임직원, CSR 강하, 고객 만족, 인권보호, 정보보호, 여신 및 투자 ESG 반영, 지속 가능 기업문화 정비, 포용적 금융 실현, 지역 상생할 동 강화, 윤리적 책임 이행, 리스크 관리, 고객 만족 및 권리 보호, 금융사고 예방 및 디지털 보안, 휴먼 캐피털, 일과 삶 균형, 노사관계, 안전보건, 인권 경영, 상생 협력, 고객 만족,정보보호 및 정보공개, 사회 공헌, 일자리 창출, 안전보건 경영, 인재경영, 인권 경영, 상생 경영, 고객만족경영, 사회 공헌, 정보보호, 인재경영, 인권 존중, 사회 공헌, 하나 파워 온 프로그램 확대, 은행 간 공동 점포 운영 및 컬처 뱅크를 통한 금융 접근성 확대, 상생경영, 인적자원개발, 임직원 포용 정책, 오케이션 제도, 안전보건, 고객만족, 정보보호, 지역사회, 기술혁신, 안전, 인권, 노동, 품질, 사회 공헌, 사업장 보건과 안전 강화, 인권 경영, 인재 육성, 지역사회 참여 등 지속 가능경영, 안전보건, 공급망 관리, 인적자원 관리, 인권 경영, 조경 소통, 정보 보안 및 개인 정보보호, 사회 공헌 활동, 사회 데이터, 안전 경영, 인재경영, 인권 경영, 정보 보안, 안전 경영, 인재경영, 인권 경영, 정보 보안, 인권 경영, 인재 선발 및 육성, 인재경영, 정보 보안, 사업장 안전보건, 인권 경영, 인재 선발 및 육성, 인재경영, 정보 보안, 사업장 안전보건, 인권 경영, 인재 선발 및 육성, 인재경영, 정보 보안, 사업장 안전보건, 인권 경영, 인재 선발 및 육성, 인재경영, 정보 보안, 사업장 안전보건, 인권 경영, 인재 육성 및 유지, 안전 및 보건, 동반성장, 공급망 관리, 품질경영, 고객 만족, 사회 공헌, 공급망 관리, 안전·환경, 고객, 구성원, 사회 공헌, With Stakeholders, 인권 경영, 인재경영, 상생 경영, 안전보건 경영, 품질경영, 정보보호, 사회 공헌, 사회를 위한 책임 경영 내재화, 고객 중심, 임직원 행복, 지역사회, 상생 협력, 임직원 존중, 금융소비자 보호, 사회 공헌, 포용 금융 확대, 혁신성장 지원, 임직원, 협력사, 지역사회, 인권, 안전 및 보건, 안전 및 보건, 안전 및 보건, 고객 중심 경영, 인재경영, 지역 사회 공헌, 고객 만족 실현, 마케팅 커뮤니케이션, 인재 관리, 조직문화, 노사관계, 고객만족경영, 안전보건 경영, 품질경영, 인재경영, 공급망 관리, 사회 공헌, 고객 중심 경영 강화, 사업모델 및 기술 혁신을 통한 포용적 금융 확대, 행복한 열린 일터 구현, 이해관계자와의 동행, 스타트업 육성 플랫폼, 금융교육 통합 플랫폼, 경영 성과 사회적 책임 실천과 나눔 경영, 헬스케어 접근성, 책임 있는 연구 개발, 제품 품질 및 안전, 인적자원 관리, 인권 보호 및 구성원의 삶의 질 향상, 사업장 안전 보건, 지속이 가능한 공급망, 책임 있는 마케팅 및 고객 관계 관리, 개인 정보 보호 및 데이터 보안, 지역사회 발전 및 기업 시민 행동, 고객만족경영, 임직원, 파트너 및 협력사, 공급망 ESG, 안전 및 보건, 개인 정보보호 및 보안, 인권, 지역사회 공헌, 임직원, 인권, 고객, 지역사회, 안전보건, 인권 경영, 품질경영, 인재경영, 동반성장, 사회 공헌, 인재경영, 상생 협력, 품질경영, 사회 공헌, 임직원, 협력사, 고객사, 사회 공헌, 인권 경영, 안전 경영, 고객 감동, 상생 경영, 인재경영, 우수인력 확보, 임직원 역량 강화, 협력적 노사 관계 구축, 사업장 안전 문화 확산, 고객 만족 및 서비스 강화, 사회 공헌활동, 임직원, 노동과 인권, 정보보호, 협력사 동반성장, 지역사회, Together with Employees, Together with Partners, 임직원 가치 향상, 안전보건, 안전하고 건강한 일터 보장, 사람이 행복한 기업 추구, 지속 가능 공급망 & 지역사회, 가치경영, 인재경영, 상생 경영, 사회 공헌, 중소기업·스타트업 지원, 삼성 미래 기술 육성 사업, 개인 정보보호, 사이버 보안, AI 윤리, 디지털 웰빙, 노동 인권, 다양성과 포용, 안전·보건, 인재 양성, 조직 문화, 책임 있는 공급망, 함께 성장하는 공급망, 임직원, 고객, 혁신, 포용 경영 실천, 훌륭한 일터 조성, 지속이 가능한 파트너십 구축, 지역사회 발전 기여, 안전한 근무 환경을 위한 안전보건 활동, 임직원의 역량 개발 및 일하는 문화 혁신,청소년 SW 교육을 통한 사회 공헌, 협력회사 ESG 지원, 혁신과 신뢰의 조직, 안전한 일터 구현, 함께하는 성장, 고객 중심 경영, 지역사회 상생발전, 나눔의 가치 실천, 협력회사 동반성장, 임직원 가치 증진, 지역사회 기여, 인권 존중, 인재경영, 안전보건, 개인 정보보호, 품질경영, 공급망 관리, 협력사 상생, 사회 공헌, 책임 있는 공급망, 지속이 가능한 일터, 건강한 지역사회, 안전 최우선 경영, 산업 안전 및 보건, 인재 채용, 유지 및 개발, 임직원 복지, 다양성&균등한 기회, 지역사회 활동, 공급망 리스크 관리, 개인 정보보호, 고객만족경영, 행복한 조직문화 조성, 파트너사 동반성장, 사회 공헌활동, 기술 혁신, 품질 경영, 공급망 관리, 상생 협력, 인권, 임직원, 안전, 지속이 가능한 공급망, 제품 책임, 기본권 보장, 임직원 가치 확대, 안전 및 보건, 사회 공헌 및 지역사회 참여, 정보보호, 인권 경영, 산업 안전보건, 조직문화, 인재 양성, 고객, 협력사, 지역사회, 인재경영, 동반성장, 사회 공헌, 카카오 크루, 파트너, 이용자, 커뮤니티, 품질 중심 경영, 고객만족경영, 안전 관리, 정보 보안, 직원 가치 창조문화, 동반성장, 사회 공헌'

# %%
all_sentence3 = '지배 구조, 윤리경영, 통합리스크 관리, 지배 구조, 컴플라이언스, 정보 보안, 리스크 관리, 건전한 지배 구조 정착, ESG 전략체계 운영, 관리, 지배 구조 체계 강화, 투명한 기업공개, 지배 구조 건전성, 전사적 리스크 관리, 윤리경영, 정보보호, Risk Management, 지배 구조, 지속 가능 거버넌스 구축, 투명한 지배 구조, 윤리경영, 리스크 관리, 지배 구조, 리스크 관리, 컴플라이언스, 지배 구조, 반부패, 이해관계자 커뮤니케이션, 지속 가능 경영 위원회, 소비자 리스크 관리 위원회 활동 등 소비자 보호 디지털금융, 지배 구조, 주요 리스크 관리, 윤리경영, 컴플라이언스, 인권 경영, 이해관계자 참여, 정도경영, 거버넌스, 리스크 관리, 지배 구조, 리스크 관리, 윤리경영, 정도경영, Compliance 경영, 이사회 및 위원회, 주주 권리 보호, 리스크 관리 및 위기관리체계, 지배 구조 데이터, 리스크 관리, 리스크 관리, 지배 구조, 리스크 관리,윤리경영, 지배 구조, 리스크 관리, 윤리경영, 지배 구조, 리스크 관리, 윤리경영, 지배 구조, 리스크 관리, 윤리경영, 지배 구조, 윤리경영, 정보 보안, 리스크 관리, 지배 구조, 정도경영, 준법경영, 정보보호, Through Transparency, 이사회, 윤리경영, 준법 경영, 리스크 관리, 투명한 기업지배구조 확산, 지배 구조, 윤리·준법 경영, 리스크 관리, 준법, 윤리경영 이행, 리스크 관리, 정보 보호, 이사회, 리스크 관리, 윤리, 건전한 지배 구조, 건전한 지배 구조, 건전한 지배 구조, 건전한 지배 구조 확립, 선제적 위험관리, 윤리, 준법 경영 강화, 지배 구조, 준법 경영, ESG 거버넌스, 지배 구조, 리스크 관리, 정보 보안, 반부패·윤리경영·공정거래, 지배 구조 건전성 확립, 윤리경영 안착, 리스크 관리,  그룹사의 이사회 내 ESG 위원회 신설, ESG 성과관리체계 구축, 금융 사기 예방 활동, 건전하고 투명한 지배 구조 확립, 기업 지배구조, 기업 윤리 및 컴플라이언스,리스크 관리, 지배 구조, 정도경영, 리스크 관리, 기업지배구조, 컴플라이언스, 리스크 관리, 지배 구조, 공급망 관리, 윤리경영, 혁신경영, 정보 보안, 지배 구조, 컴플라이언스, 정보보호, 리스크 관리, 이사회 중심 책임 경영, 윤리, 준법 경영, 리스크 경영, 건전한 지배 구조, 윤리 및 준법 경영, 리스크 관리, 건전한 지배 구조, 주주 친화경영, 정보보호 관리체계, 준법경영, 통합리스크 관리, 지배 구조, 윤리경영, 투명한 지배 구조, 윤리경영, 기업 지배구조, 리스크 관리, 원칙을 지키는 문화 정착, 기회를 향한 도전 장려, 체계적인 리스크 관리 실천, 지배 구조, 리스크 관리, 컴플라이언스, 윤리경영, 책임 광물 관리 투명성 확보, 지배 구조, 윤리·준법 경영, 선진 지배 구조 정착, 주주 가치 제고, 준법·윤리경영 실천, 리스크 관리 강화, ESG 위원회 운영,AI 윤리 헌장 및 개인 정보 보호, 디지털 책임 강화, 건전한 지배 구조, 기업윤리 실천, 리스크 관리, 지배 구조, 투명경영과 리스크 관리, 지배 구조, 통합리스크 관리, 윤리 준법 경영, 안정적 지배 구조, 투명경영과 리스크 관리, 지속 가능경영 체계 구축 및 운영, 지배 구조 건전성, 윤리, 준법 경영, 리스크 통합 관리, 정보 보안 관리 강화, 지배 구조, 주주 권리 보호, 준법 경영, 리스크 관리, 거버넌스, 정도경영 및 컴플라이언스, 정보 보안, 리스크 관리, 주주 가치 제고, 경쟁력 있는 이사회, 감사 기구 운영, 리스크 관리, 컴플라이언스 경영, 지배 구조, 윤리경영, 컴플라이언스, 지배 구조, 리스크 관리, 윤리경영, 인권 경영, 기업 지배구조, 리스크 관리, 윤리경영, 지배 구조, 윤리경영, 주주 권리 보호, 리스크 관리'

# %% [markdown]
# # 특성을 고려한 단어 빈도수

# %%
all_sentence1 = all_sentence1.split(', ')
all_sentence2 = all_sentence2.split(', ')
all_sentence3 = all_sentence3.split(', ')

# %%
dic = {'E' : all_sentence1, 'S' : all_sentence2, 'G' : all_sentence3}
df_all = pd.DataFrame.from_dict(dic, orient = 'index')
df_all = df_all.transpose()

# %%
df_all
# Out:
#                       E           S         G
# 0                  환경경영    고객 감동 경영     지배 구조
# 1               기후변화 대응        인재경영      윤리경영
# 2            친환경 사업장 구축       안전 경영  통합리스크 관리
# 3            친환경 타이어 확대       상생 경영     지배 구조
# 4    탄소중립을 향한 에너지 경영 실천     지역사회 참여    컴플라이언스
# ..                  ...         ...       ...
# 323                None       안전 관리      None
# 324                None       정보 보안      None
# 325                None  직원 가치 창조문화      None
# 326                None        동반성장      None
# 327                None       사회 공헌      None
#
# [328 rows x 3 columns]

# %%
df_values_E = df_all[['E']].value_counts()

# %%
df_values_S = df_all[['S']].value_counts()

# %%
df_values_G = df_all[['G']].value_counts()

# %%
dic = {'E' : df_values_E, 'S' : df_values_S, 'G' : df_values_G}
df_values = pd.DataFrame.from_dict(dic, orient = 'index')
df_values = df_values.transpose()

# %%
df_values
# Out:
#                     E   S    G
# 기후변화 대응          29.0 NaN  NaN
# 환경경영             18.0 NaN  NaN
# 그린경영              5.0 NaN  NaN
# 친환경 경영            5.0 NaN  NaN
# 기후 위기 대응          4.0 NaN  NaN
# ...               ...  ..  ...
# 리스크 통합 관리         NaN NaN  1.0
# 리스크 관리,윤리경영       NaN NaN  1.0
# 리스크 관리 및 위기관리체계   NaN NaN  1.0
# 리스크 관리 강화         NaN NaN  1.0
# 혁신경영              NaN NaN  1.0
#
# [362 rows x 3 columns]

# %%
df_values.to_csv('ESG_count.csv', encoding='cp949')

# %% [markdown]
# 산업군 정리, 해당 산업이 어떤 단어를 많이 사용하는 지 확인하기, TF-IDF or groupby
