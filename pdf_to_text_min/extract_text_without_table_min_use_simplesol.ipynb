# %%
# pip install PyPDF2
# pip install PDFFileReader
# pip install pdf

import PyPDF2
from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
import os

filename = "NH투자증권.pdf"
filepath = os.path.join("../pdf_to_text_min",filename)

# PDF의 Total 페이지를 읽어오기 
fp = open(filepath, 'rb')
total_pages = PyPDF2.PdfFileReader(fp).numPages

# pdfminer로 페이지별 텍스트 가져오기 
page_text = {}
for page_no in range(total_pages):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    device = TextConverter(rsrcmgr, retstr, laparams=LAParams())
    fb = open(filepath, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    caching = True
    maxpages = 0
    pagenos = [page_no]
    for page in PDFPage.get_pages(fb, pagenos, maxpages = maxpages, 
                              caching = caching, check_extractable = True):
        interpreter.process_page(page)
        page_text[page_no] = retstr.getvalue()
    fp.close()
    device.close()
    retstr.close()
    
#print(page_text[1][:-1])
"""
# 원하는 페이지 첫번째 []에 입력 
# 1 page 내용 출력
#print(page_text[1])
#print(page_text[1][:-1])

print("Start")
with open("NH_paper.txt", 'w',encoding="UTF-8") as f:
    for idx in range(len(page_text)):
        f.write(page_text[idx])
print("Finish")
"""
# Out:
# '\n# 원하는 페이지 첫번째 []에 입력 \n# 1 page 내용 출력\n#print(page_text[1])\n#print(page_text[1][:-1])\n\nprint("Start")\nwith open("NH_paper.txt", \'w\',encoding="UTF-8") as f:\n    for idx in range(len(page_text)):\n        f.write(page_text[idx])\nprint("Finish")\n'

# %%
page_text[20][:200]
# Out:
# '021\n\nINTRODUCTION\n\nKEY HIGHLIGHTS\n\nTOWARDS THE ESG LEADERSHIP\n\nTOWARDS A SUSTAINABLE FUTURE\n\nAPPENDIX\n\n함께하는 마을 만들기    NH투자증권은 ‘함께하는 마을 만들기’ 활동을 통해 지속적으로 농촌의 일손 돕기뿐만 \n\n아니라 마을의 숙원사업과 농산물 직거래장터 등을 지원하는 등'

# %%
print(len(page_text[20]))
# Out:
# 3514

# %%
index_freq_list = []
index_loc_list = []
total_text = page_text[20]
start_point = 0
past_index = 0
index = 0

while(True):
    index = total_text.find('\n',start_point+1,len(total_text)-1)
    if index == -1:
        break
    
    start_point = index
    index_loc_list.append([past_index,index])
    index_freq_list.append(index-past_index)
    past_index = index

# %%
print(len(index_freq_list))
print(len(index_loc_list))
# Out:
# 310
# 310

# %%
print(index_freq_list)
# Out:
# [3, 1, 13, 1, 15, 1, 27, 1, 29, 1, 9, 1, 63, 1, 65, 1, 67, 1, 63, 1, 27, 1, 18, 1, 3, 1, 5, 1, 5, 1, 5, 1, 9, 1, 12, 1, 15, 1, 8, 1, 3, 1, 3, 1, 6, 1, 3, 1, 3, 1, 3, 1, 6, 1, 3, 1, 3, 1, 5, 1, 6, 1, 3, 1, 37, 1, 63, 1, 64, 1, 61, 1, 62, 1, 64, 1, 65, 1, 66, 1, 60, 1, 62, 1, 34, 1, 22, 1, 3, 1, 5, 1, 5, 1, 5, 1, 9, 1, 7, 1, 12, 1, 12, 1, 8, 1, 3, 1, 6, 1, 5, 1, 6, 1, 4, 1, 3, 1, 6, 1, 5, 1, 6, 1, 4, 1, 26, 1, 3, 1, 5, 1, 5, 1, 9, 1, 12, 1, 12, 1, 8, 1, 2, 1, 5, 1, 5, 1, 4, 1, 3, 1, 6, 1, 5, 1, 6, 1, 4, 1, 2, 1, 4, 1, 5, 1, 4, 1, 62, 1, 59, 1, 60, 1, 61, 1, 16, 1, 23, 1, 6, 1, 7, 1, 8, 1, 3, 1, 8, 1, 22, 1, 12, 1, 35, 1, 3, 1, 11, 1, 3, 1, 5, 1, 5, 1, 5, 1, 6, 1, 64, 1, 60, 1, 63, 1, 39, 1, 3, 1, 9, 1, 9, 1, 9, 1, 5, 1, 5, 1, 5, 1, 5, 1, 22, 1, 3, 1, 3, 1, 3, 1, 4, 1, 3, 1, 3, 1, 4, 1, 2, 1, 3, 1, 3, 1, 4, 1, 2, 1, 18, 1, 66, 1, 6, 1, 13, 1, 6, 1, 14, 1, 13, 1, 59, 1, 68, 1, 60, 1, 33, 1, 8, 1, 67, 1, 66, 1, 67, 1, 67, 1, 61, 1, 64, 1, 58, 1, 62, 1, 65, 1, 64, 1, 59, 1, 59, 1, 62, 1]

# %%
total_text
# Out:
# '021\n\nINTRODUCTION\n\nKEY HIGHLIGHTS\n\nTOWARDS THE ESG LEADERSHIP\n\nTOWARDS A SUSTAINABLE FUTURE\n\nAPPENDIX\n\n함께하는 마을 만들기    NH투자증권은 ‘함께하는 마을 만들기’ 활동을 통해 지속적으로 농촌의 일손 돕기뿐만 \n\n아니라 마을의 숙원사업과 농산물 직거래장터 등을 지원하는 등 실효적인 지원 활동을 펼치고 있습니다. 2021년에는 \n\n코로나19 이슈로 인해 농촌을 직접 방문하기 어려운 상황이었으나 방문 횟수 33회, 참여 임직원 수 437명으로 전년 \n\n대비 15% 감소한 방문 횟수를 기록하였습니다. 당사는 앞으로도 지역사회 내 유대관계를 바탕으로 사회적 책임을 \n\n실천하고 나눔 공유의 활동을 지속할 예정입니다.\n\n함께하는 마을 만들기 활동 현황\n\n구분\n\n2019\n\n2020\n\n2021\n\n마을 수 (개)\n\n농촌방문 횟수 (회)\n\n참여직원 수(누적) (명)\n\n참여율 (%)\n\n32\n\n67\n\n1,661\n\n55\n\n30\n\n39\n\n1,807\n\n60\n\n31\n\n331)\n\n4371)\n\n15\n\n1) 코로나19 영향으로 참여직원 수와 대면 방문횟수는 감소하였음\n\n중소농가 육성 지원활동     NH투자증권은 중앙회 창업농지원센터, 농우바이오와 함께 중소농가를 육성하기 위해 \n\n힘쓰고 있습니다. 그 방안으로 농가 상품판매 지원은 물론이고 한 걸음 더 나아가 현재 농촌이 직면한 현실과 이에 \n\n도전하는 농업인들의 이야기를 소개하여 궁극적인 농가소득 증대에 기여하고 있습니다. 또한, 유통망의 다양화에 \n\n따라 크라우드펀딩과 스마트스토어 등의 여러 온라인 유통망을 활용하도록 하여 더 실효적인 판로 개척을 지원하고 \n\n있습니다. 크라우드펀딩은 올해로 6년째 이어지고 있으며, 펀딩금액, 연간 상품 공급능력, 농가의 업무 협조 등을 \n\n고려한 우수 농가 선정 및 지원 사업 또한 진행하고 있습니다. 지원 대상 농가는 2017년 24개 농가를 시작으로 \n\n지속적으로 확대해 나가고자 노력하고 있으며, 2021년에는 743%의 달성률을 성취하였습니다. 아울러 선발된 4개의 \n\n농가에 네이버 스마트스토어를 개설하도록 지원하여 안정적인 판로를 구축하였고 이는 농가의 자생력을 갖출 수 \n\n있도록 하는 밑거름이 되었습니다. 당사는 소비자가 양질의 농산물을 구매할 수 있는 플랫폼을 구축할 수 있도록 \n\n지원하고 많은 농가를 대상으로 사업을 확대해 나갈 것입니다.\n\n중소농가 육성을 위한 크라우드펀딩 현황\n\n구분\n\n2019\n\n2020\n\n2021\n\n지원농가 (개)\n\n펀딩 (건)\n\n목표금액 (백만 원)\n\n달성금액 (백만 원)\n\n달성률 (%)\n\n22\n\n5,106\n\n44.5\n\n182.7\n\n411\n\n24\n\n5,570\n\n43.5\n\n223.0\n\n513\n\n중소농가 육성을 위한 스마트스토어 기획전 현황\n\n구분\n\n2020\n\n2021\n\n지원농가 (개)\n\n목표금액 (백만 원)\n\n달성금액 (백만 원)\n\n달성률 (%)\n\n4\n\n11.0\n\n62.6\n\n570\n\n24\n\n6,495\n\n28.0\n\n208.0\n\n743\n\n4\n\n4.0\n\n17.3\n\n433\n\n천사펀드     2005년에 시작된 ‘천사펀드’는 NGO와 함께 사회적 취약계층과 어린이를 대상으로 지원하는 \n\nNH투자증권의 대표적인 사회공헌 사업입니다. 임직원들이 자발적으로 나서서 매월 급여의 일정부분을 기부해 \n\n후원기금을 조성하고, 다양한 지원 프로그램 중 원하는 프로그램을 지정하여 실시하는 방식입니다. 당사에서도 \n\n임직원들의 후원 기금에 일정 금액을 더해 지원하고 있으며, 이는 소외된 이웃과 아동 그리고 의료 낙후지역의 \n\n건강지원 사업에 전달됩니다.\n\n후원기관별 천사펀드 지원 현황 및 금액 \n\n후원 기관\n\n밀알복지재단\n\n한국소아암재단\n\n비고\n\n결식아동 지원\n\n소아암 환우 치료비 및 긴급생계비 지원\n\n원주의료사업 협동조합\n\n의료 낙후 농촌지역 주민대상 건강검진 및 건강관리교육 등 지원\n\n합계\n\n(단위: 백만 원)\n\n금액\n\n60.0\n\n50.0\n\n36.4\n\n146.4\n\n사랑의 나눔 헌혈 행사     당사는 임직원을 대상으로 1년에 3회 사랑의 나눔 헌혈 행사를 운영하고 있습니다. \n\n매년 NH투자증권의 대표이사를 포함한 전 임직원들이 참석하여 적극적인 헌혈활동을 진행하고 있습니다. 특히 \n\n2021년 코로나19의 확산으로 국내 헌혈 참여자가 급격하게 줄어드는 상황에도 임직원들은 자발적으로 헌혈행사에 \n\n참여함으로써 혈액 수급이 부족한 상황에 도움을 주고자 노력하였습니다.\n\n년도\n\n1회 (참여자)\n\n2회 (참여자)\n\n3회 (참여자)\n\n2019\n\n2020\n\n2021\n\n2022\n\n* 2022년 2회, 3회는 진행 예정\n\n41\n\n94\n\n73\n\n101\n\n43\n\n89\n\n141\n\n-\n\n63\n\n63\n\n111\n\n-\n\n울진, 강원 산불피해 기부 현황\n\n울진, 강원 산불피해 기부     NH투자증권 임직원들은 2022년 3월 발생했던 울진, 강원 산불피해 성금 모금에 \n\n회사기부금\n\n135,000,000원\n\n직원기부금\n\n130,622,000 원\n\n265,622,000원\n\n적극적으로 참여하였습니다. 대형산불로 인해 특별재난지역으로 선포된 울진, 강원 지역 일대의 피해복구 및 \n\n농가지원을 위한 임직원 성금을 1차, 2차로 나누어 모금하였으며, 전 직원의 97%인 2,970명이 자발적으로 산불피해 \n\n성금모금에 적극적으로 동참하였습니다. 모금된 기부금은 사단법인 도농상생국민운동본부로 전달하여 울진, 강원 \n\n일대 피해 복구 및 이재민 지원을 위해 활용할 예정입니다.\n\n교육 장학제도\n\nNH투자증권은 2005년부터 지속적으로 저소득층 가정 청소년의 학업을 지원해 왔으며 2017년부터는 농촌지역 중심으로 \n\n장학생을 우선선발하여 지원하고 있습니다. 매년 복지 사각지대에 놓인 저소득층 가정의 우수 고등학생 40명을 선발하여 \n\n연간 1인 400만 원의 장학금을 지급하여 기숙사비, 특별활동비, 그 외 학습에 필요한 비용 등으로 활용할 수 있도록 \n\n지원하고 대학입학 시 200만 원의 입학 격려금을 지원하여 학업을 이어 나갈 수 있도록 하고 있습니다. 2021년까지 \n\n배출한 장학생은 총 600명으로, 금전적인 지원뿐만 아니라 당사 임직원들이 장학생들의 멘토가 되어 지속적인 \n\n유대관계를 형성하여 학교생활과 취업에 대한 조언을 해주는 등 비금전적인 지원 또한 아끼지 않고 있습니다. 당사는 \n\n앞으로도 어려운 상황에 놓인 청소년들의 더 나은 미래를 지원함으로써 사회적 가치를 실현해 나가겠습니다.\n\n1사1교 금융교육 NH투자증권은 초등학교 및 중학교 학생들을 대상으로 1사1교 금융교육을 진행하고 있습니다. \n\n2021년은 월배중학교 학생들을 대상으로 중학생을 위한 금융의 이해를 위한 금융의 개념 및 금융상품의 종류에 대한 \n\n수업을 진행하였습니다. 코로나19로 인하여 집합교육이 불가한 점을 고려하여 반별로 수업을 시행하고, 직접 강의를 \n\n지원하지 못한 반은 강의자료를 전달하여 담당 선생님이 교육을 진행하도록 운영하여 최대한 많은 학생들에게 \n\n금융지식을 전달하고자 노력하였습니다. 이 외에도 서울 대곡초등학교 학생을 대상으로 저축과 투자와 관련한 \n\n주제로 수업을 진행하는 등 NH투자증권은 청소년의 금융 지식 함양을 위한 노력을 지속적으로 이어오고 있습니다.\n\n\x0c'

# %%
min_val = sum(index_freq_list)/len(index_freq_list)
min_val
# Out:
# 11.329032258064515

# %%
min_val = sum(index_freq_list)/len(index_freq_list)
pre_text = total_text[:]

for i in range(len(index_freq_list)):
    if index_freq_list[i]<min_val+10:
        start_point = index_loc_list[i][0]
        end_point = index_loc_list[i][1]
        
        if total_text[start_point:end_point] != "\n":
            pre_text = pre_text.replace(total_text[start_point:end_point],'')
            print("삭제 단어: ",total_text[start_point:end_point])
        else: 
            print("삭제 단어: 개행문자")

print(pre_text)
# Out:
# 삭제 단어:  021
# 삭제 단어: 개행문자
# 삭제 단어:
# INTRODUCTION
# 삭제 단어: 개행문자
# 삭제 단어:
# KEY HIGHLIGHTS
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# APPENDIX
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 함께하는 마을 만들기 활동 현황
# 삭제 단어: 개행문자
# 삭제 단어:
# 구분
# 삭제 단어: 개행문자
# 삭제 단어:
# 2019
# 삭제 단어: 개행문자
# 삭제 단어:
# 2020
# 삭제 단어: 개행문자
# 삭제 단어:
# 2021
# 삭제 단어: 개행문자
# 삭제 단어:
# 마을 수 (개)
# 삭제 단어: 개행문자
# 삭제 단어:
# 농촌방문 횟수 (회)
# 삭제 단어: 개행문자
# 삭제 단어:
# 참여직원 수(누적) (명)
# 삭제 단어: 개행문자
# 삭제 단어:
# 참여율 (%)
# 삭제 단어: 개행문자
# 삭제 단어:
# 32
# 삭제 단어: 개행문자
# 삭제 단어:
# 67
# 삭제 단어: 개행문자
# 삭제 단어:
# 1,661
# 삭제 단어: 개행문자
# 삭제 단어:
# 55
# 삭제 단어: 개행문자
# 삭제 단어:
# 30
# 삭제 단어: 개행문자
# 삭제 단어:
# 39
# 삭제 단어: 개행문자
# 삭제 단어:
# 1,807
# 삭제 단어: 개행문자
# 삭제 단어:
# 60
# 삭제 단어: 개행문자
# 삭제 단어:
# 31
# 삭제 단어: 개행문자
# 삭제 단어:
# 331)
# 삭제 단어: 개행문자
# 삭제 단어:
# 4371)
# 삭제 단어: 개행문자
# 삭제 단어:
# 15
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 구분
# 삭제 단어: 개행문자
# 삭제 단어:
# 2019
# 삭제 단어: 개행문자
# 삭제 단어:
# 2020
# 삭제 단어: 개행문자
# 삭제 단어:
# 2021
# 삭제 단어: 개행문자
# 삭제 단어:
# 지원농가 (개)
# 삭제 단어: 개행문자
# 삭제 단어:
# 펀딩 (건)
# 삭제 단어: 개행문자
# 삭제 단어:
# 목표금액 (백만 원)
# 삭제 단어: 개행문자
# 삭제 단어:
# 달성금액 (백만 원)
# 삭제 단어: 개행문자
# 삭제 단어:
# 달성률 (%)
# 삭제 단어: 개행문자
# 삭제 단어:
# 22
# 삭제 단어: 개행문자
# 삭제 단어:
# 5,106
# 삭제 단어: 개행문자
# 삭제 단어:
# 44.5
# 삭제 단어: 개행문자
# 삭제 단어:
# 182.7
# 삭제 단어: 개행문자
# 삭제 단어:
# 411
# 삭제 단어: 개행문자
# 삭제 단어:
# 24
# 삭제 단어: 개행문자
# 삭제 단어:
# 5,570
# 삭제 단어: 개행문자
# 삭제 단어:
# 43.5
# 삭제 단어: 개행문자
# 삭제 단어:
# 223.0
# 삭제 단어: 개행문자
# 삭제 단어:
# 513
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 구분
# 삭제 단어: 개행문자
# 삭제 단어:
# 2020
# 삭제 단어: 개행문자
# 삭제 단어:
# 2021
# 삭제 단어: 개행문자
# 삭제 단어:
# 지원농가 (개)
# 삭제 단어: 개행문자
# 삭제 단어:
# 목표금액 (백만 원)
# 삭제 단어: 개행문자
# 삭제 단어:
# 달성금액 (백만 원)
# 삭제 단어: 개행문자
# 삭제 단어:
# 달성률 (%)
# 삭제 단어: 개행문자
# 삭제 단어:
# 4
# 삭제 단어: 개행문자
# 삭제 단어:
# 11.0
# 삭제 단어: 개행문자
# 삭제 단어:
# 62.6
# 삭제 단어: 개행문자
# 삭제 단어:
# 570
# 삭제 단어: 개행문자
# 삭제 단어:
# 24
# 삭제 단어: 개행문자
# 삭제 단어:
# 6,495
# 삭제 단어: 개행문자
# 삭제 단어:
# 28.0
# 삭제 단어: 개행문자
# 삭제 단어:
# 208.0
# 삭제 단어: 개행문자
# 삭제 단어:
# 743
# 삭제 단어: 개행문자
# 삭제 단어:
# 4
# 삭제 단어: 개행문자
# 삭제 단어:
# 4.0
# 삭제 단어: 개행문자
# 삭제 단어:
# 17.3
# 삭제 단어: 개행문자
# 삭제 단어:
# 433
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 건강지원 사업에 전달됩니다.
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 후원 기관
# 삭제 단어: 개행문자
# 삭제 단어:
# 밀알복지재단
# 삭제 단어: 개행문자
# 삭제 단어:
# 한국소아암재단
# 삭제 단어: 개행문자
# 삭제 단어:
# 비고
# 삭제 단어: 개행문자
# 삭제 단어:
# 결식아동 지원
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 원주의료사업 협동조합
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 합계
# 삭제 단어: 개행문자
# 삭제 단어:
# (단위: 백만 원)
# 삭제 단어: 개행문자
# 삭제 단어:
# 금액
# 삭제 단어: 개행문자
# 삭제 단어:
# 60.0
# 삭제 단어: 개행문자
# 삭제 단어:
# 50.0
# 삭제 단어: 개행문자
# 삭제 단어:
# 36.4
# 삭제 단어: 개행문자
# 삭제 단어:
# 146.4
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 년도
# 삭제 단어: 개행문자
# 삭제 단어:
# 1회 (참여자)
# 삭제 단어: 개행문자
# 삭제 단어:
# 2회 (참여자)
# 삭제 단어: 개행문자
# 삭제 단어:
# 3회 (참여자)
# 삭제 단어: 개행문자
# 삭제 단어:
# 2019
# 삭제 단어: 개행문자
# 삭제 단어:
# 2020
# 삭제 단어: 개행문자
# 삭제 단어:
# 2021
# 삭제 단어: 개행문자
# 삭제 단어:
# 2022
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 41
# 삭제 단어: 개행문자
# 삭제 단어:
# 94
# 삭제 단어: 개행문자
# 삭제 단어:
# 73
# 삭제 단어: 개행문자
# 삭제 단어:
# 101
# 삭제 단어: 개행문자
# 삭제 단어:
# 43
# 삭제 단어: 개행문자
# 삭제 단어:
# 89
# 삭제 단어: 개행문자
# 삭제 단어:
# 141
# 삭제 단어: 개행문자
# 삭제 단어:
# -
# 삭제 단어: 개행문자
# 삭제 단어:
# 63
# 삭제 단어: 개행문자
# 삭제 단어:
# 63
# 삭제 단어: 개행문자
# 삭제 단어:
# 111
# 삭제 단어: 개행문자
# 삭제 단어:
# -
# 삭제 단어: 개행문자
# 삭제 단어:
# 울진, 강원 산불피해 기부 현황
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 회사기부금
# 삭제 단어: 개행문자
# 삭제 단어:
# 135,000,000원
# 삭제 단어: 개행문자
# 삭제 단어:
# 직원기부금
# 삭제 단어: 개행문자
# 삭제 단어:
# 130,622,000 원
# 삭제 단어: 개행문자
# 삭제 단어:
# 265,622,000원
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어:
# 교육 장학제도
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
# 삭제 단어: 개행문자
#
#
#
#
# TOWARDS THE ESG LEADERSHIP
#
# TOWARDS A SUSTAINABLE FUTURE
#
#
# 함께하는 마을 만들기    NH투자증권은 ‘함께하는 마을 만들기’ 활동을 통해 지속적으로 농촌의 일손 돕기뿐만
#
# 아니라 마을의 숙원사업과 농산물 직거래장터 등을 지원하는 등 실효적인 지원 활동을 펼치고 있습니다. 2년에는
#
# 코로나19 이슈로 인해 농촌을 직접 방문하기 어려운 상황이었으나 방문 횟수 33회, 참여 임직원 수 437명으로 전년
#
# 대비 15% 감소한 방문 횟수를 기록하였습니다. 당사는 앞으로도 지역사회 내 유대관계를 바탕으로 사회적 책임을
#
# 실천하고 나눔 공유의 활동을 지속할 예정입니다.
#
#
#
#
#
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 1) 코로나19 영향으로 참여직원 수와 대면 방문횟수는 감소하였음
#
# 중소농가 육성 지원활동     NH투자증권은 중앙회 창업농지원센터, 농우바이오와 함께 중소농가를 육성하기 위해
#
# 힘쓰고 있습니다. 그 방안으로 농가 상품판매 지원은 물론이고 한 걸음 더 나아가 현재 농촌이 직면한 현실과 이에
#
# 도전하는 농업인들의 이야기를 소개하여 궁극적인 농가소득 증대에 기여하고 있습니다. 또한, 유통망의 다양화에
#
# 따라 크라우드펀딩과 스마트스토어 등의 여러 온라인 유통망을 활용하도록 하여 더 실효적인 판로 개척을 지원하고
#
# 있습니다. 크라우드펀딩은 올해로 6년째 이어지고 있으며, 펀딩금액, 연간 상품 공급능력, 농가의 업무 협조 등을
#
# 고려한 우수 농가 선정 및 지원 사업 또한 진행하고 있습니다. 지원 대상 농가는 2017년 24개 농가를 시작으로
#
# 지속적으로 확대해 나가고자 노력하고 있으며, 2년에는 743%의 달성률을 성취하였습니다. 아울러 선발된 4개의
#
# 농가에 네이버 스마트스토어를 개설하도록 지원하여 안정적인 판로를 구축하였고 이는 농가의 자생력을 갖출 수
#
# 있도록 하는 밑거름이 되었습니다. 당사는 소비자가 양질의 농산물을 구매할 수 있는 플랫폼을 구축할 수 있도록
#
# 지원하고 많은 농가를 대상으로 사업을 확대해 나갈 것입니다.
#
# 중소농가 육성을 위한 크라우드펀딩 현황
#
#
#
#
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
# 3.0
#
#
# 중소농가 육성을 위한 스마트스토어 기획전 현황
#
#
#
# 2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# .0
#
# 33
#
# 천사펀드     2005년에 시작된 ‘천사펀드’는 NGO와 함께 사회적 취약계층과 어린이를 대상으로 지원하는
#
# NH투자증권의 대표적인 사회공헌 사업입니다. 임직원들이 자발적으로 나서서 매월 급여의 일정부분을 기부해
#
# 후원기금을 조성하고, 다양한 지원 프로그램 중 원하는 프로그램을 지정하여 실시하는 방식입니다. 당사에서도
#
# 임직원들의 후원 기금에 일정 금액을 더해 지원하고 있으며, 이는 소외된 이웃과 아동 그리고 의료 낙후지역의
#
#
# 후원기관별 천사펀드 지원 현황 및 금액
#
#
#
#
#
#
# 소아암 환우 치료비 및 긴급생계비 지원
#
#
# 의료 낙후 농촌지역 주민대상 건강검진 및 건강관리교육 등 지원
#
#
#
# .0
#
#
#
#
# 사랑의 나눔 헌혈 행사     당사는 임직원을 대상으로 1년에 3회 사랑의 나눔 헌혈 행사를 운영하고 있습니다.
#
# 매년 NH투자증권의 대표이사를 포함한 전 임직원들이 참석하여 적극적인 헌혈활동을 진행하고 있습니다. 특히
#
# 2년 코로나19의 확산으로 국내 헌혈 참여자가 급격하게 줄어드는 상황에도 임직원들은 자발적으로 헌혈행사에
#
# 참여함으로써 혈액 수급이 부족한 상황에 도움을 주고자 노력하였습니다.
#
#
#
#
#
#
#
# 2
#
#
# * 2022년 2회, 3회는 진행 예정
# 1
#
#
#
# 3
#
#
#
#
#
#
#
#
#
# 울진, 강원 산불피해 기부     NH투자증권 임직원들은 2022년 3월 발생했던 울진, 강원 산불피해 성금 모금에
#
#
#
#
#
#
# 적극적으로 참여하였습니다. 대형산불로 인해 특별재난지역으로 선포된 울진, 강원 지역 일대의 피해복구 및
#
# 농가지원을 위한 임직원 성금을 1차, 2차로 나누어 모금하였으며, 전 직원의 97%인 2,970명이 자발적으로 산불피해
#
# 성금모금에 적극적으로 동참하였습니다. 모금된 기부금은 사단법인 도농상생국민운동본부로 전달하여 울진, 강원
#
# 일대 피해 복구 및 이재민 지원을 위해 활용할 예정입니다.
#
#
# NH투자증권은 2005년부터 지속적으로 저소득층 가정 청소년의 학업을 지원해 왔으며 2017년부터는 농촌지역 중심으로
#
# 장학생을 우선선발하여 지원하고 있습니다. 매년 복지 사각지대에 놓인 저소득층 가정의 우수 고등학생 40명을 선발하여
#
# 연간 1인 400만 원의 장학금을 지급하여 기숙사비, 특별활동비, 그 외 학습에 필요한 비용 등으로 활용할 수 있도록
#
# 지원하고 대학입학 시 200만 원의 입학 격려금을 지원하여 학업을 이어 나갈 수 있도록 하고 있습니다. 2년까지
#
# 배출한 장학생은 총 600명으로, 금전적인 지원뿐만 아니라 당사 임직원들이 장학생들의 멘토가 되어 지속적인
#
# 유대관계를 형성하여 학교생활과 취업에 대한 조언을 해주는 등 비금전적인 지원 또한 아끼지 않고 있습니다. 당사는
#
# 앞으로도 어려운 상황에 놓인 청소년들의 더 나은 미래를 지원함으로써 사회적 가치를 실현해 나가겠습니다.
#
# 1사1교 금융교육 NH투자증권은 초등학교 및 중학교 학생들을 대상으로 1사1교 금융교육을 진행하고 있습니다.
#
# 2년은 월배중학교 학생들을 대상으로 중학생을 위한 금융의 이해를 위한 금융의 개념 및 금융상품의 종류에 대한
#
# 수업을 진행하였습니다. 코로나19로 인하여 집합교육이 불가한 점을 고려하여 반별로 수업을 시행하고, 직접 강의를
#
# 지원하지 못한 반은 강의자료를 전달하여 담당 선생님이 교육을 진행하도록 운영하여 최대한 많은 학생들에게
#
# 금융지식을 전달하고자 노력하였습니다. 이 외에도 서울 대곡초등학교 학생을 대상으로 저축과 투자와 관련한
#
# 주제로 수업을 진행하는 등 NH투자증권은 청소년의 금융 지식 함양을 위한 노력을 지속적으로 이어오고 있습니다.

# %%
sum(index_freq_list)
# Out:
# 3512

# %%
min_val = sum(index_freq_list)/len(index_freq_list)
print(min_val)
# Out:
# 11.329032258064515

# %%
page_text[20]
# Out:
# '021\n\nINTRODUCTION\n\nKEY HIGHLIGHTS\n\nTOWARDS THE ESG LEADERSHIP\n\nTOWARDS A SUSTAINABLE FUTURE\n\nAPPENDIX\n\n함께하는 마을 만들기    NH투자증권은 ‘함께하는 마을 만들기’ 활동을 통해 지속적으로 농촌의 일손 돕기뿐만 \n\n아니라 마을의 숙원사업과 농산물 직거래장터 등을 지원하는 등 실효적인 지원 활동을 펼치고 있습니다. 2021년에는 \n\n코로나19 이슈로 인해 농촌을 직접 방문하기 어려운 상황이었으나 방문 횟수 33회, 참여 임직원 수 437명으로 전년 \n\n대비 15% 감소한 방문 횟수를 기록하였습니다. 당사는 앞으로도 지역사회 내 유대관계를 바탕으로 사회적 책임을 \n\n실천하고 나눔 공유의 활동을 지속할 예정입니다.\n\n함께하는 마을 만들기 활동 현황\n\n구분\n\n2019\n\n2020\n\n2021\n\n마을 수 (개)\n\n농촌방문 횟수 (회)\n\n참여직원 수(누적) (명)\n\n참여율 (%)\n\n32\n\n67\n\n1,661\n\n55\n\n30\n\n39\n\n1,807\n\n60\n\n31\n\n331)\n\n4371)\n\n15\n\n1) 코로나19 영향으로 참여직원 수와 대면 방문횟수는 감소하였음\n\n중소농가 육성 지원활동     NH투자증권은 중앙회 창업농지원센터, 농우바이오와 함께 중소농가를 육성하기 위해 \n\n힘쓰고 있습니다. 그 방안으로 농가 상품판매 지원은 물론이고 한 걸음 더 나아가 현재 농촌이 직면한 현실과 이에 \n\n도전하는 농업인들의 이야기를 소개하여 궁극적인 농가소득 증대에 기여하고 있습니다. 또한, 유통망의 다양화에 \n\n따라 크라우드펀딩과 스마트스토어 등의 여러 온라인 유통망을 활용하도록 하여 더 실효적인 판로 개척을 지원하고 \n\n있습니다. 크라우드펀딩은 올해로 6년째 이어지고 있으며, 펀딩금액, 연간 상품 공급능력, 농가의 업무 협조 등을 \n\n고려한 우수 농가 선정 및 지원 사업 또한 진행하고 있습니다. 지원 대상 농가는 2017년 24개 농가를 시작으로 \n\n지속적으로 확대해 나가고자 노력하고 있으며, 2021년에는 743%의 달성률을 성취하였습니다. 아울러 선발된 4개의 \n\n농가에 네이버 스마트스토어를 개설하도록 지원하여 안정적인 판로를 구축하였고 이는 농가의 자생력을 갖출 수 \n\n있도록 하는 밑거름이 되었습니다. 당사는 소비자가 양질의 농산물을 구매할 수 있는 플랫폼을 구축할 수 있도록 \n\n지원하고 많은 농가를 대상으로 사업을 확대해 나갈 것입니다.\n\n중소농가 육성을 위한 크라우드펀딩 현황\n\n구분\n\n2019\n\n2020\n\n2021\n\n지원농가 (개)\n\n펀딩 (건)\n\n목표금액 (백만 원)\n\n달성금액 (백만 원)\n\n달성률 (%)\n\n22\n\n5,106\n\n44.5\n\n182.7\n\n411\n\n24\n\n5,570\n\n43.5\n\n223.0\n\n513\n\n중소농가 육성을 위한 스마트스토어 기획전 현황\n\n구분\n\n2020\n\n2021\n\n지원농가 (개)\n\n목표금액 (백만 원)\n\n달성금액 (백만 원)\n\n달성률 (%)\n\n4\n\n11.0\n\n62.6\n\n570\n\n24\n\n6,495\n\n28.0\n\n208.0\n\n743\n\n4\n\n4.0\n\n17.3\n\n433\n\n천사펀드     2005년에 시작된 ‘천사펀드’는 NGO와 함께 사회적 취약계층과 어린이를 대상으로 지원하는 \n\nNH투자증권의 대표적인 사회공헌 사업입니다. 임직원들이 자발적으로 나서서 매월 급여의 일정부분을 기부해 \n\n후원기금을 조성하고, 다양한 지원 프로그램 중 원하는 프로그램을 지정하여 실시하는 방식입니다. 당사에서도 \n\n임직원들의 후원 기금에 일정 금액을 더해 지원하고 있으며, 이는 소외된 이웃과 아동 그리고 의료 낙후지역의 \n\n건강지원 사업에 전달됩니다.\n\n후원기관별 천사펀드 지원 현황 및 금액 \n\n후원 기관\n\n밀알복지재단\n\n한국소아암재단\n\n비고\n\n결식아동 지원\n\n소아암 환우 치료비 및 긴급생계비 지원\n\n원주의료사업 협동조합\n\n의료 낙후 농촌지역 주민대상 건강검진 및 건강관리교육 등 지원\n\n합계\n\n(단위: 백만 원)\n\n금액\n\n60.0\n\n50.0\n\n36.4\n\n146.4\n\n사랑의 나눔 헌혈 행사     당사는 임직원을 대상으로 1년에 3회 사랑의 나눔 헌혈 행사를 운영하고 있습니다. \n\n매년 NH투자증권의 대표이사를 포함한 전 임직원들이 참석하여 적극적인 헌혈활동을 진행하고 있습니다. 특히 \n\n2021년 코로나19의 확산으로 국내 헌혈 참여자가 급격하게 줄어드는 상황에도 임직원들은 자발적으로 헌혈행사에 \n\n참여함으로써 혈액 수급이 부족한 상황에 도움을 주고자 노력하였습니다.\n\n년도\n\n1회 (참여자)\n\n2회 (참여자)\n\n3회 (참여자)\n\n2019\n\n2020\n\n2021\n\n2022\n\n* 2022년 2회, 3회는 진행 예정\n\n41\n\n94\n\n73\n\n101\n\n43\n\n89\n\n141\n\n-\n\n63\n\n63\n\n111\n\n-\n\n울진, 강원 산불피해 기부 현황\n\n울진, 강원 산불피해 기부     NH투자증권 임직원들은 2022년 3월 발생했던 울진, 강원 산불피해 성금 모금에 \n\n회사기부금\n\n135,000,000원\n\n직원기부금\n\n130,622,000 원\n\n265,622,000원\n\n적극적으로 참여하였습니다. 대형산불로 인해 특별재난지역으로 선포된 울진, 강원 지역 일대의 피해복구 및 \n\n농가지원을 위한 임직원 성금을 1차, 2차로 나누어 모금하였으며, 전 직원의 97%인 2,970명이 자발적으로 산불피해 \n\n성금모금에 적극적으로 동참하였습니다. 모금된 기부금은 사단법인 도농상생국민운동본부로 전달하여 울진, 강원 \n\n일대 피해 복구 및 이재민 지원을 위해 활용할 예정입니다.\n\n교육 장학제도\n\nNH투자증권은 2005년부터 지속적으로 저소득층 가정 청소년의 학업을 지원해 왔으며 2017년부터는 농촌지역 중심으로 \n\n장학생을 우선선발하여 지원하고 있습니다. 매년 복지 사각지대에 놓인 저소득층 가정의 우수 고등학생 40명을 선발하여 \n\n연간 1인 400만 원의 장학금을 지급하여 기숙사비, 특별활동비, 그 외 학습에 필요한 비용 등으로 활용할 수 있도록 \n\n지원하고 대학입학 시 200만 원의 입학 격려금을 지원하여 학업을 이어 나갈 수 있도록 하고 있습니다. 2021년까지 \n\n배출한 장학생은 총 600명으로, 금전적인 지원뿐만 아니라 당사 임직원들이 장학생들의 멘토가 되어 지속적인 \n\n유대관계를 형성하여 학교생활과 취업에 대한 조언을 해주는 등 비금전적인 지원 또한 아끼지 않고 있습니다. 당사는 \n\n앞으로도 어려운 상황에 놓인 청소년들의 더 나은 미래를 지원함으로써 사회적 가치를 실현해 나가겠습니다.\n\n1사1교 금융교육 NH투자증권은 초등학교 및 중학교 학생들을 대상으로 1사1교 금융교육을 진행하고 있습니다. \n\n2021년은 월배중학교 학생들을 대상으로 중학생을 위한 금융의 이해를 위한 금융의 개념 및 금융상품의 종류에 대한 \n\n수업을 진행하였습니다. 코로나19로 인하여 집합교육이 불가한 점을 고려하여 반별로 수업을 시행하고, 직접 강의를 \n\n지원하지 못한 반은 강의자료를 전달하여 담당 선생님이 교육을 진행하도록 운영하여 최대한 많은 학생들에게 \n\n금융지식을 전달하고자 노력하였습니다. 이 외에도 서울 대곡초등학교 학생을 대상으로 저축과 투자와 관련한 \n\n주제로 수업을 진행하는 등 NH투자증권은 청소년의 금융 지식 함양을 위한 노력을 지속적으로 이어오고 있습니다.\n\n\x0c'

# %%
print(page_text[20])
# Out:
# 021
#
# INTRODUCTION
#
# KEY HIGHLIGHTS
#
# TOWARDS THE ESG LEADERSHIP
#
# TOWARDS A SUSTAINABLE FUTURE
#
# APPENDIX
#
# 함께하는 마을 만들기    NH투자증권은 ‘함께하는 마을 만들기’ 활동을 통해 지속적으로 농촌의 일손 돕기뿐만
#
# 아니라 마을의 숙원사업과 농산물 직거래장터 등을 지원하는 등 실효적인 지원 활동을 펼치고 있습니다. 2021년에는
#
# 코로나19 이슈로 인해 농촌을 직접 방문하기 어려운 상황이었으나 방문 횟수 33회, 참여 임직원 수 437명으로 전년
#
# 대비 15% 감소한 방문 횟수를 기록하였습니다. 당사는 앞으로도 지역사회 내 유대관계를 바탕으로 사회적 책임을
#
# 실천하고 나눔 공유의 활동을 지속할 예정입니다.
#
# 함께하는 마을 만들기 활동 현황
#
# 구분
#
# 2019
#
# 2020
#
# 2021
#
# 마을 수 (개)
#
# 농촌방문 횟수 (회)
#
# 참여직원 수(누적) (명)
#
# 참여율 (%)
#
# 32
#
# 67
#
# 1,661
#
# 55
#
# 30
#
# 39
#
# 1,807
#
# 60
#
# 31
#
# 331)
#
# 4371)
#
# 15
#
# 1) 코로나19 영향으로 참여직원 수와 대면 방문횟수는 감소하였음
#
# 중소농가 육성 지원활동     NH투자증권은 중앙회 창업농지원센터, 농우바이오와 함께 중소농가를 육성하기 위해
#
# 힘쓰고 있습니다. 그 방안으로 농가 상품판매 지원은 물론이고 한 걸음 더 나아가 현재 농촌이 직면한 현실과 이에
#
# 도전하는 농업인들의 이야기를 소개하여 궁극적인 농가소득 증대에 기여하고 있습니다. 또한, 유통망의 다양화에
#
# 따라 크라우드펀딩과 스마트스토어 등의 여러 온라인 유통망을 활용하도록 하여 더 실효적인 판로 개척을 지원하고
#
# 있습니다. 크라우드펀딩은 올해로 6년째 이어지고 있으며, 펀딩금액, 연간 상품 공급능력, 농가의 업무 협조 등을
#
# 고려한 우수 농가 선정 및 지원 사업 또한 진행하고 있습니다. 지원 대상 농가는 2017년 24개 농가를 시작으로
#
# 지속적으로 확대해 나가고자 노력하고 있으며, 2021년에는 743%의 달성률을 성취하였습니다. 아울러 선발된 4개의
#
# 농가에 네이버 스마트스토어를 개설하도록 지원하여 안정적인 판로를 구축하였고 이는 농가의 자생력을 갖출 수
#
# 있도록 하는 밑거름이 되었습니다. 당사는 소비자가 양질의 농산물을 구매할 수 있는 플랫폼을 구축할 수 있도록
#
# 지원하고 많은 농가를 대상으로 사업을 확대해 나갈 것입니다.
#
# 중소농가 육성을 위한 크라우드펀딩 현황
#
# 구분
#
# 2019
#
# 2020
#
# 2021
#
# 지원농가 (개)
#
# 펀딩 (건)
#
# 목표금액 (백만 원)
#
# 달성금액 (백만 원)
#
# 달성률 (%)
#
# 22
#
# 5,106
#
# 44.5
#
# 182.7
#
# 411
#
# 24
#
# 5,570
#
# 43.5
#
# 223.0
#
# 513
#
# 중소농가 육성을 위한 스마트스토어 기획전 현황
#
# 구분
#
# 2020
#
# 2021
#
# 지원농가 (개)
#
# 목표금액 (백만 원)
#
# 달성금액 (백만 원)
#
# 달성률 (%)
#
# 4
#
# 11.0
#
# 62.6
#
# 570
#
# 24
#
# 6,495
#
# 28.0
#
# 208.0
#
# 743
#
# 4
#
# 4.0
#
# 17.3
#
# 433
#
# 천사펀드     2005년에 시작된 ‘천사펀드’는 NGO와 함께 사회적 취약계층과 어린이를 대상으로 지원하는
#
# NH투자증권의 대표적인 사회공헌 사업입니다. 임직원들이 자발적으로 나서서 매월 급여의 일정부분을 기부해
#
# 후원기금을 조성하고, 다양한 지원 프로그램 중 원하는 프로그램을 지정하여 실시하는 방식입니다. 당사에서도
#
# 임직원들의 후원 기금에 일정 금액을 더해 지원하고 있으며, 이는 소외된 이웃과 아동 그리고 의료 낙후지역의
#
# 건강지원 사업에 전달됩니다.
#
# 후원기관별 천사펀드 지원 현황 및 금액
#
# 후원 기관
#
# 밀알복지재단
#
# 한국소아암재단
#
# 비고
#
# 결식아동 지원
#
# 소아암 환우 치료비 및 긴급생계비 지원
#
# 원주의료사업 협동조합
#
# 의료 낙후 농촌지역 주민대상 건강검진 및 건강관리교육 등 지원
#
# 합계
#
# (단위: 백만 원)
#
# 금액
#
# 60.0
#
# 50.0
#
# 36.4
#
# 146.4
#
# 사랑의 나눔 헌혈 행사     당사는 임직원을 대상으로 1년에 3회 사랑의 나눔 헌혈 행사를 운영하고 있습니다.
#
# 매년 NH투자증권의 대표이사를 포함한 전 임직원들이 참석하여 적극적인 헌혈활동을 진행하고 있습니다. 특히
#
# 2021년 코로나19의 확산으로 국내 헌혈 참여자가 급격하게 줄어드는 상황에도 임직원들은 자발적으로 헌혈행사에
#
# 참여함으로써 혈액 수급이 부족한 상황에 도움을 주고자 노력하였습니다.
#
# 년도
#
# 1회 (참여자)
#
# 2회 (참여자)
#
# 3회 (참여자)
#
# 2019
#
# 2020
#
# 2021
#
# 2022
#
# * 2022년 2회, 3회는 진행 예정
#
# 41
#
# 94
#
# 73
#
# 101
#
# 43
#
# 89
#
# 141
#
# -
#
# 63
#
# 63
#
# 111
#
# -
#
# 울진, 강원 산불피해 기부 현황
#
# 울진, 강원 산불피해 기부     NH투자증권 임직원들은 2022년 3월 발생했던 울진, 강원 산불피해 성금 모금에
#
# 회사기부금
#
# 135,000,000원
#
# 직원기부금
#
# 130,622,000 원
#
# 265,622,000원
#
# 적극적으로 참여하였습니다. 대형산불로 인해 특별재난지역으로 선포된 울진, 강원 지역 일대의 피해복구 및
#
# 농가지원을 위한 임직원 성금을 1차, 2차로 나누어 모금하였으며, 전 직원의 97%인 2,970명이 자발적으로 산불피해
#
# 성금모금에 적극적으로 동참하였습니다. 모금된 기부금은 사단법인 도농상생국민운동본부로 전달하여 울진, 강원
#
# 일대 피해 복구 및 이재민 지원을 위해 활용할 예정입니다.
#
# 교육 장학제도
#
# NH투자증권은 2005년부터 지속적으로 저소득층 가정 청소년의 학업을 지원해 왔으며 2017년부터는 농촌지역 중심으로
#
# 장학생을 우선선발하여 지원하고 있습니다. 매년 복지 사각지대에 놓인 저소득층 가정의 우수 고등학생 40명을 선발하여
#
# 연간 1인 400만 원의 장학금을 지급하여 기숙사비, 특별활동비, 그 외 학습에 필요한 비용 등으로 활용할 수 있도록
#
# 지원하고 대학입학 시 200만 원의 입학 격려금을 지원하여 학업을 이어 나갈 수 있도록 하고 있습니다. 2021년까지
#
# 배출한 장학생은 총 600명으로, 금전적인 지원뿐만 아니라 당사 임직원들이 장학생들의 멘토가 되어 지속적인
#
# 유대관계를 형성하여 학교생활과 취업에 대한 조언을 해주는 등 비금전적인 지원 또한 아끼지 않고 있습니다. 당사는
#
# 앞으로도 어려운 상황에 놓인 청소년들의 더 나은 미래를 지원함으로써 사회적 가치를 실현해 나가겠습니다.
#
# 1사1교 금융교육 NH투자증권은 초등학교 및 중학교 학생들을 대상으로 1사1교 금융교육을 진행하고 있습니다.
#
# 2021년은 월배중학교 학생들을 대상으로 중학생을 위한 금융의 이해를 위한 금융의 개념 및 금융상품의 종류에 대한
#
# 수업을 진행하였습니다. 코로나19로 인하여 집합교육이 불가한 점을 고려하여 반별로 수업을 시행하고, 직접 강의를
#
# 지원하지 못한 반은 강의자료를 전달하여 담당 선생님이 교육을 진행하도록 운영하여 최대한 많은 학생들에게
#
# 금융지식을 전달하고자 노력하였습니다. 이 외에도 서울 대곡초등학교 학생을 대상으로 저축과 투자와 관련한
#
# 주제로 수업을 진행하는 등 NH투자증권은 청소년의 금융 지식 함양을 위한 노력을 지속적으로 이어오고 있습니다.

# %%
# 원하는 페이지 첫번째 []에 입력 
# 1 page 내용 출력
print(page_text[1])
print(page_text[1][:-1])

print("Start")
with open("NH_paper.txt", 'w',encoding="UTF-8") as f:
    for idx in range(len(page_text)):
        f.write(page_text[idx])
print("Finish")
# Out:
# ABOUT THIS REPORT
#
# 보고서 개요
# NH투자증권은 2018년부터 지속가능경영보고서를 정기적으로 발간해오고 있으며,
# 2020년부터는 연차보고서(Annual Report)와 지속가능경영보고서(Sustainability
# Report)를 통합한 형태의 지속가능통합보고서(Integrated Report)로 발간하고 있습니다.
# 본 보고서는 NH투자증권의 주요 활동과 성과를 보고하고 있으며 경제, 사회 및 환경적
# 가치 창출 과정에 대해 상세히 보고하고 있습니다.
#
# 보고서 작성기준
# GRI(Global Reporting Initiative) Standards의 핵심적 방법(Core Option)에 부합하도록
# 작성되었으며 UNGC 10대 원칙을 적용하였습니다. 아울러 산업 특성에 따른 주요 이슈를
# 반영하고자 SASB(Sustainability Accounting Standard Board) 산업 표준과 TCFD(Task
# Force on Climate-Related Financial Disclosures)의 공시 권고안을 준수하고 있습니다.
# 또한, 한국채택 국제회계기준을 따라 통합보고위원회(IIRC, International Integrated
# Reporting Council)의 IR Framework를 참조하여 작성하였습니다.
#
# 보고 기간
# 본 보고서는 NH투자증권의 2021년 1월 1일부터 12월 31일까지의 활동과 성과를
# 담고 있습니다. 또한 일부 주요 정량성과의 경우에는 2019부터 2021년까지 3년 간의
# 데이터를 수록하여 시계열로 분석하였고 이해관계자에게 영향을 미칠 수 있는 중요
# 정보의 경우 2021년 이전 혹은 2022년 상반기 내용도 포함하였습니다.
#
# 보고 범위
# 보고 범위는 NH투자증권의 본사 및 지점 등 국내 사업장이며 자회사는 포함하지
# 않습니다. 본 보고서에 기재된 환경 성과의 범위는 본사에 한정하였으며 필요한 경우 지점
# 또는 해외사업장의 활동 및 성과를 포함하였습니다. 중요 이슈별 보고경계에 대해서는
# 별도의 주석으로 표기하였습니다.
#
# 보고서 검증
# 본 보고서는 독립적인 외부 전문 검증기관인 한국경영인증원(KMR)으로부터 검증을
# 받았습니다. 검증 과정에서는 국제적 검증표준인 AA1000AS(v3 2020), AA1000AP
# 2018 기준에 따라 검증을 실시하여 보고내용의 객관성과 신뢰성을 제고하였습니다. 세부
# 검증 결과는 본 보고서 부록의 ‘제3자 검증의견서’에서 확인할 수 있습니다.
#
# Contact Information
# 이해관계자들의 정보 접근성을 높이기 위해 보고서를 NH투자증권의 홈페이지에도
# 공개하고 있으며 PDF 포맷으로 다운로드할 수 있습니다. 보고서에 대한 의견을 이메일,
# 전화, 우편 등 다양한 경로를 통해 수렴하고 있습니다.
#
# •주소  서울시 영등포구 여의대로 108 파크원 NH금융타워(타워2)
# •전화
# •이메일
#
# +82-2-768-7351
# investor@nhqv.com
#
# NH투자증권 지속가능통합보고서
#
# CONTENTS
#
# 1
#
# 2
# 3
#
# 4
#
# 5
#
# INTRODUCTION
#
# 003
# 004
# 007
# 011
#
# CEO Message
# Company Profile
# 사업별 현황
# NHIS Value Chain
#
# KEY HIGHLIGHTS
#
# 012
#
# ESG Integration at NHIS
#
# TOWARDS THE
# ESG LEADERSHIP
#
# 019
# 020
# 027
#
# Environmental Part
# Social Part
# Governance Part
#
# TOWARDS
# A SUSTAINABLE FUTURE
#
# 031
# 033
# 036
# 038
#
# Issue #01 디지털 금융 및 플랫폼 경쟁력 확보
# Issue #02 고객 커뮤니케이션 확대
# Issue #03 금융소비자 보호
# Issue #04 임직원 역량 개발
#
# APPENDIX
#
# 042
# 043
# 044
# 048
# 049
# 049
# 051
# 054
# 055
# 056
# 056
# 057
# 057
# 058
#
# 중대성 평가
# Management Approach
# 재무성과표
# 이해관계자 커뮤니케이션 채널
# 조세정책
# GRI Standards Index
# SASB Index
# TCFD
# 제3자 검증의견서
# 온실가스 검증 성명서
# UNGC
# UN SDGs
# 2020-2021 주요 수상내역
# 협회 가입 현황
#
#
# ABOUT THIS REPORT
#
# 보고서 개요
# NH투자증권은 2018년부터 지속가능경영보고서를 정기적으로 발간해오고 있으며,
# 2020년부터는 연차보고서(Annual Report)와 지속가능경영보고서(Sustainability
# Report)를 통합한 형태의 지속가능통합보고서(Integrated Report)로 발간하고 있습니다.
# 본 보고서는 NH투자증권의 주요 활동과 성과를 보고하고 있으며 경제, 사회 및 환경적
# 가치 창출 과정에 대해 상세히 보고하고 있습니다.
#
# 보고서 작성기준
# GRI(Global Reporting Initiative) Standards의 핵심적 방법(Core Option)에 부합하도록
# 작성되었으며 UNGC 10대 원칙을 적용하였습니다. 아울러 산업 특성에 따른 주요 이슈를
# 반영하고자 SASB(Sustainability Accounting Standard Board) 산업 표준과 TCFD(Task
# Force on Climate-Related Financial Disclosures)의 공시 권고안을 준수하고 있습니다.
# 또한, 한국채택 국제회계기준을 따라 통합보고위원회(IIRC, International Integrated
# Reporting Council)의 IR Framework를 참조하여 작성하였습니다.
#
# 보고 기간
# 본 보고서는 NH투자증권의 2021년 1월 1일부터 12월 31일까지의 활동과 성과를
# 담고 있습니다. 또한 일부 주요 정량성과의 경우에는 2019부터 2021년까지 3년 간의
# 데이터를 수록하여 시계열로 분석하였고 이해관계자에게 영향을 미칠 수 있는 중요
# 정보의 경우 2021년 이전 혹은 2022년 상반기 내용도 포함하였습니다.
#
# 보고 범위
# 보고 범위는 NH투자증권의 본사 및 지점 등 국내 사업장이며 자회사는 포함하지
# 않습니다. 본 보고서에 기재된 환경 성과의 범위는 본사에 한정하였으며 필요한 경우 지점
# 또는 해외사업장의 활동 및 성과를 포함하였습니다. 중요 이슈별 보고경계에 대해서는
# 별도의 주석으로 표기하였습니다.
#
# 보고서 검증
# 본 보고서는 독립적인 외부 전문 검증기관인 한국경영인증원(KMR)으로부터 검증을
# 받았습니다. 검증 과정에서는 국제적 검증표준인 AA1000AS(v3 2020), AA1000AP
# 2018 기준에 따라 검증을 실시하여 보고내용의 객관성과 신뢰성을 제고하였습니다. 세부
# 검증 결과는 본 보고서 부록의 ‘제3자 검증의견서’에서 확인할 수 있습니다.
#
# Contact Information
# 이해관계자들의 정보 접근성을 높이기 위해 보고서를 NH투자증권의 홈페이지에도
# 공개하고 있으며 PDF 포맷으로 다운로드할 수 있습니다. 보고서에 대한 의견을 이메일,
# 전화, 우편 등 다양한 경로를 통해 수렴하고 있습니다.
#
# •주소  서울시 영등포구 여의대로 108 파크원 NH금융타워(타워2)
# •전화
# •이메일
#
# +82-2-768-7351
# investor@nhqv.com
#
# NH투자증권 지속가능통합보고서
#
# CONTENTS
#
# 1
#
# 2
# 3
#
# 4
#
# 5
#
# INTRODUCTION
#
# 003
# 004
# 007
# 011
#
# CEO Message
# Company Profile
# 사업별 현황
# NHIS Value Chain
#
# KEY HIGHLIGHTS
#
# 012
#
# ESG Integration at NHIS
#
# TOWARDS THE
# ESG LEADERSHIP
#
# 019
# 020
# 027
#
# Environmental Part
# Social Part
# Governance Part
#
# TOWARDS
# A SUSTAINABLE FUTURE
#
# 031
# 033
# 036
# 038
#
# Issue #01 디지털 금융 및 플랫폼 경쟁력 확보
# Issue #02 고객 커뮤니케이션 확대
# Issue #03 금융소비자 보호
# Issue #04 임직원 역량 개발
#
# APPENDIX
#
# 042
# 043
# 044
# 048
# 049
# 049
# 051
# 054
# 055
# 056
# 056
# 057
# 057
# 058
#
# 중대성 평가
# Management Approach
# 재무성과표
# 이해관계자 커뮤니케이션 채널
# 조세정책
# GRI Standards Index
# SASB Index
# TCFD
# 제3자 검증의견서
# 온실가스 검증 성명서
# UNGC
# UN SDGs
# 2020-2021 주요 수상내역
# 협회 가입 현황
#
#
# Start
# Finish

# %%
import pandas as pd
import tabula
import re

page_num = 0
preproReport = []

while page_num != len(page_text):

    # pdf에 있는 table을 탐지
    df = tabula.read_pdf(filepath, pages = str(page_num + 1), multiple_tables = True, guess = True)

    # page_num 쪽의 내용을 리스트로 변환
    page_content = page_text[page_num]
    pageTolist = re.split('[ /\n]+', page_content)

    print("Working on page(PDF): ",page_num+1)
    # 탐지한 table에 대해서 전처리 작업
    # 열 이름이 Unnamed:~ 로 탐지되는 것들은 쓸모 없는 것들이 많아서 해당 열을 삭제
    for table_num in range(len(df)):
        table = df[table_num].loc[:,df[table_num].columns.str.startswith('Unnamed:') == False]
        # 탐지한 table이 데이터프레인 형태인데, 이를 문자열로 변환하며 개행문자"\n" 제거
        tableToStr = table.to_string().replace("\n","")
        # 변환한 문자열을 공백을 기준으로 나눠 리스트에 담아준다
        tableTolist = tableToStr.split(" ")
        # 리스트로 담아주면서 의미없는 공백과 NaN을 제거
        tableTolist = [i for i in tableTolist if i != '' and i != 'NaN']
        print("테이블 길이: ",len(tableTolist))

        # table이 pdf의 페이지에서 어디에 위치하는지 찾는 작업 시작
        # page_num 쪽의 내용을 리스트로 변환한 pageTolist에서, table의 내용이 몇 번째 인덱스에 위치하는지 찾는다.
        # pageTolist의 table_start번째 인덱스부터 table_finish번째 인덱스까지 한칸씩 이동하며, table의 내용이 pageTolist의 어느 인덱스에 위치하는지 찾는다.
        # 최적의 인덱스 위치를 찾기 위해, 유사도를 확인한다.
        # 여기서 유사도란, tableTolist와 pageTolist[table_start:table_finish]이 유사한 정도를 의미한다 (교집합)
        table_start = 0
        table_finish = len(tableTolist)- 1
        simil = 0
        best_start = 0
        best_finish = 0

        while table_finish < len(pageTolist):
            simil_temp = len(set(pageTolist[table_start:table_finish]).intersection(tableTolist)) / len(tableTolist)
            if simil_temp > simil:
                simil = simil_temp
                best_start = table_start
                best_finish = table_finish
            table_start += 1
            table_finish += 1
        del pageTolist[best_start:best_finish+1]
        print("Table number: ",table_num+1)
    preproReport.append(pageTolist)
    page_num += 1
# Out:
# Working on page(PDF):  1
# Working on page(PDF):  2
# Working on page(PDF):  3
# Working on page(PDF):  4
# Working on page(PDF):  5
# 테이블 길이:  12
# Table number:  1
# 테이블 길이:  10
# Table number:  2
# Working on page(PDF):  6
# 테이블 길이:  67
# Table number:  1
# Working on page(PDF):  7
# Working on page(PDF):  8
# 테이블 길이:  179
# Table number:  1
# Working on page(PDF):  9
# 테이블 길이:  536
# Table number:  1
# Working on page(PDF):  10
# Working on page(PDF):  11
# Working on page(PDF):  12
# 테이블 길이:  53
# Table number:  1
# Working on page(PDF):  13
# Working on page(PDF):  14
# Working on page(PDF):  15
# Working on page(PDF):  16
# Working on page(PDF):  17
# Working on page(PDF):  18
# Working on page(PDF):  19
# 테이블 길이:  169
# Table number:  1
# Working on page(PDF):  20
# 테이블 길이:  146
# Table number:  1
# Working on page(PDF):  21
# Working on page(PDF):  22
# 테이블 길이:  343
# Table number:  1
# Working on page(PDF):  23
# Working on page(PDF):  24
# 테이블 길이:  323
# Table number:  1
# Working on page(PDF):  25
# 테이블 길이:  247
# Table number:  1
# Working on page(PDF):  26
# Working on page(PDF):  27
# 테이블 길이:  9
# Table number:  1
# 테이블 길이:  50
# Table number:  2
# Working on page(PDF):  28
# 테이블 길이:  61
# Table number:  1
# 테이블 길이:  40
# Table number:  2
# Working on page(PDF):  29
# 테이블 길이:  27
# Table number:  1
# 테이블 길이:  42
# Table number:  2
# Working on page(PDF):  30
# Working on page(PDF):  31
# 테이블 길이:  25
# Table number:  1
# Working on page(PDF):  32
# Working on page(PDF):  33
# Working on page(PDF):  34
# 테이블 길이:  309
# Table number:  1
# Working on page(PDF):  35
# Working on page(PDF):  36
# Working on page(PDF):  37
# 테이블 길이:  515
# Table number:  1
# Working on page(PDF):  38
# 테이블 길이:  82
# Table number:  1
# 테이블 길이:  26
# Table number:  2
# 테이블 길이:  24
# Table number:  3
# 테이블 길이:  78
# Table number:  4
# Working on page(PDF):  39
# 테이블 길이:  417
# Table number:  1
# Working on page(PDF):  40
# 테이블 길이:  531
# Table number:  1
# Working on page(PDF):  41
# Working on page(PDF):  42
# 테이블 길이:  16
# Table number:  1
# Working on page(PDF):  43
# 테이블 길이:  12
# Table number:  1
# Working on page(PDF):  44
# 테이블 길이:  343
# Table number:  1
# Working on page(PDF):  45
# 테이블 길이:  87
# Table number:  1
# 테이블 길이:  48
# Table number:  2
# Working on page(PDF):  46
# 테이블 길이:  115
# Table number:  1
# Working on page(PDF):  47
# 테이블 길이:  8
# Table number:  1
# 테이블 길이:  159
# Table number:  2
# 테이블 길이:  135
# Table number:  3
# Working on page(PDF):  48
# 테이블 길이:  137
# Table number:  1
# Working on page(PDF):  49
# 테이블 길이:  23
# Table number:  1
# Working on page(PDF):  50
# 테이블 길이:  11
# Table number:  1
# 테이블 길이:  15
# Table number:  2
# 테이블 길이:  20
# Table number:  3
# Working on page(PDF):  51
# 테이블 길이:  21
# Table number:  1
# 테이블 길이:  17
# Table number:  2
# Working on page(PDF):  52
# Working on page(PDF):  53
# Working on page(PDF):  54
# Working on page(PDF):  55
# Working on page(PDF):  56
# 테이블 길이:  8
# Table number:  1
# 테이블 길이:  15
# Table number:  2
# Working on page(PDF):  57
# 테이블 길이:  5
# Table number:  1
# 테이블 길이:  4
# Table number:  2
# 테이블 길이:  4
# Table number:  3
# 테이블 길이:  4
# Table number:  4
# 테이블 길이:  51
# Table number:  5
# 테이블 길이:  5
# Table number:  6
# 테이블 길이:  4
# Table number:  7
# 테이블 길이:  4
# Table number:  8
# 테이블 길이:  4
# Table number:  9
# 테이블 길이:  4
# Table number:  10
# 테이블 길이:  4
# Table number:  11
# 테이블 길이:  4
# Table number:  12
# 테이블 길이:  4
# Table number:  13
# 테이블 길이:  4
# Table number:  14
# 테이블 길이:  4
# Table number:  15
# Working on page(PDF):  58
# 테이블 길이:  33
# Table number:  1
# Working on page(PDF):  59

# %%
# NH 투자증권 보고서 19페이지
preproReport[22]
# Out:
# ['023',
#  'INTRODUCTION',
#  'KEY',
#  'HIGHLIGHTS',
#  'TOWARDS',
#  'THE',
#  'ESG',
#  'LEADERSHIP',
#  'TOWARDS',
#  'A',
#  'SUSTAINABLE',
#  'FUTURE',
#  'APPENDIX',
#  'NH임직원',
#  '고충처리',
#  '제도',
#  'NH투자증권은',
#  '임직원에',
#  '대한',
#  '상시적인',
#  '고충처리를',
#  '위해',
#  '사내',
#  '홈페이지의',
#  '‘소통과',
#  '공감’',
#  '코너를',
#  'CEO',
#  '직통',
#  '소통채널로',
#  '운영하고',
#  '있습니다.',
#  '2021년',
#  '한',
#  '해',
#  '동안',
#  '총',
#  '36개의',
#  '자유의견과',
#  '고충사항이',
#  '게시되면서',
#  '크게',
#  '활성화되었으며,',
#  '임직원들은',
#  '이',
#  '공간에서',
#  '서로의',
#  '고충을',
#  '공유하고',
#  '질의,',
#  '답변하고',
#  '있습니다.',
#  '아울러',
#  '각',
#  '주제에',
#  '부합하는',
#  '담당부서는',
#  '직접',
#  '답변을',
#  '게시하여',
#  '임직원들의',
#  '고충을',
#  '귀담아듣고',
#  '실효적으로',
#  '해소하기',
#  '위해',
#  '노력하고',
#  '있습니다.',
#  '이외에도',
#  '임직원들은',
#  '사내',
#  '인사관리',
#  '시스템',
#  '‘HRIS’를',
#  '통해',
#  '고충에',
#  '대해',
#  '자유롭게',
#  '제보하고',
#  '인사본부',
#  '내',
#  '고충처리',
#  '담당직원으로부터',
#  '개인적인',
#  '상담을',
#  '제공받을',
#  '수',
#  '있습니다.',
#  '임직원',
#  '인권교육',
#  '프로그램',
#  'NH투자증권은',
#  '관계법령에',
#  '의거하여',
#  '임직원의',
#  '직장',
#  '내',
#  '인권보호',
#  '및',
#  '인식개선을',
#  '위한',
#  '인권교육을',
#  '정기적으로',
#  '실시합니다.',
#  '인권교육은',
#  '전',
#  '임직원을',
#  '대상으로',
#  '하며,',
#  '성희롱',
#  '예방교육',
#  '외에',
#  '장애인',
#  '인식개선',
#  '및',
#  '직장내',
#  '괴롭힘',
#  '방지',
#  '교육을',
#  '시행하고',
#  '있습니다.',
#  '임직원',
#  '인권교육',
#  '프로그램',
#  '참여',
#  '현황',
#  '구분',
#  '2019',
#  '2020',
#  '2021',
#  '3,056',
#  '3,045',
#  '2,990',
#  '3,043',
#  '2,948',
#  '3,137',
#  '성희롱',
#  '예방교육',
#  '직장내',
#  '괴롭힘',
#  '방지',
#  '장애인',
#  '인식개선',
#  '임직원',
#  '다양성',
#  '(단위:',
#  '명)',
#  '3,191',
#  '3,191',
#  '3,191',
#  '다양한',
#  '구성원',
#  'NH투자증권은',
#  '양성평등이',
#  '실현되는',
#  '일터를',
#  '구축하기',
#  '위하여',
#  '여성직원',
#  '및',
#  '여성관리자',
#  '비율을',
#  '단계적으로',
#  '확대하고',
#  '있습니다.',
#  '아울러',
#  '취약',
#  '계층인',
#  '장애인,',
#  '국가보훈자,',
#  '지역소재',
#  '학교',
#  '출신자,',
#  '사회적',
#  '약자',
#  '등',
#  '사회형평적',
#  '채용을',
#  '확대하고',
#  '정착시키기',
#  '위하여',
#  '지속적으로',
#  '노력하고',
#  '있습니다.',
#  '2021년',
#  '전체',
#  '임직원',
#  '중',
#  '여성',
#  '비율은',
#  '41.9%,',
#  '전체',
#  '관리자',
#  '중',
#  '여성비율은',
#  '26.1%로',
#  '각각의',
#  '수치',
#  '모두',
#  '최근',
#  '3년간',
#  '증가하는',
#  '추세를',
#  '보이고',
#  '구분',
#  '2019',
#  '2020',
#  '2021',
#  '(단위:',
#  '%)',
#  '40.1',
#  '22.0',
#  '27.1',
#  '44.5',
#  '7.6',
#  '3.1',
#  '1.1',
#  '40.2',
#  '23.7',
#  '26.8',
#  '45.3',
#  '7.4',
#  '3.1',
#  '1.1',
#  '41.9',
#  '26.1',
#  '30.8',
#  '46.6',
#  '7.8',
#  '2.8',
#  '1.1',
#  '있습니다.',
#  '임직원의',
#  '다양성',
#  '여성',
#  '리더십',
#  '직급',
#  '계약',
#  '형태',
#  '전체',
#  '근로자',
#  '중',
#  '여성',
#  '비율',
#  '전체',
#  '관리자1)',
#  '중',
#  '여성',
#  '비율',
#  '계약직',
#  '중',
#  '여성',
#  '비율',
#  '정규직',
#  '중',
#  '여성',
#  '비율',
#  '고졸인재',
#  '비율',
#  '기타',
#  '임직원',
#  '다양성',
#  '비율',
#  '보훈직원',
#  '비율',
#  '장애인',
#  '비율',
#  '1)',
#  '관리자:',
#  '과장급',
#  '이상',
#  '윤리',
#  '및',
#  '컴플라이언스',
#  '투명한',
#  '조직',
#  '운영',
#  '윤리경영',
#  '추진조직',
#  'NH투자증권',
#  '윤리경영위원회는',
#  '체계적인',
#  '윤리경영의',
#  '추진을',
#  '목적으로',
#  '설치하여',
#  '운영하고',
#  '있는',
#  '최고의사결정',
#  '기구입니다.',
#  '위원장인',
#  '대표이사를',
#  '필두로',
#  '경영지원',
#  '총괄임원,',
#  'WM사업부대표,',
#  '경영전략본부장,',
#  '인사담당본부장,',
#  '준법감시인으로',
#  '이루어져',
#  '있으며,',
#  '준법감시인은',
#  '컴플라이언스부의',
#  '윤리경영위원회',
#  '업무',
#  '지원을',
#  '주관하고',
#  '있습니다.',
#  '윤리경영위원회의',
#  '원활한',
#  '운영을',
#  '지원하기',
#  '위해',
#  '산하에',
#  '윤리경영',
#  '사무국을',
#  '설치하여,',
#  '윤리경영',
#  '교육,',
#  '신고센터',
#  '운영,',
#  '실태조사',
#  '등과',
#  '같은',
#  '전사적',
#  '윤리경영',
#  '전파와',
#  '실천을',
#  '위한',
#  '제반',
#  '업무를',
#  '수행하도록',
#  '하고',
#  '있습니다.',
#  'i',
#  'p',
#  'h',
#  's',
#  'r',
#  'e',
#  'd',
#  'a',
#  'e',
#  'L',
#  'G',
#  'S',
#  'E',
#  'e',
#  'h',
#  't',
#  's',
#  'd',
#  'r',
#  'a',
#  'w',
#  'o',
#  'T',
#  '이사회',
#  '(최종',
#  '책임자)',
#  '대표이사',
#  '(감독책임)',
#  '내부통제위원회',
#  '설치',
#  '(분기별',
#  '1회',
#  '이상',
#  '회의',
#  '개최)',
#  '준법감시인',
#  '(이사회',
#  '및',
#  '대표이사의',
#  '지휘를',
#  '받아',
#  '업무를',
#  '수행)',
#  '준법감시부서',
#  '(준법감시인의',
#  '직무',
#  '수행)',
#  '센터장·부서장',
#  '컴플라이언스',
#  '매니저',
#  'NH투자증권',
#  '윤리헌장',
#  '1.',
#  '우리',
#  '농협금융은',
#  '농업인을',
#  '위한',
#  '금융사업을',
#  '효율적으로',
#  '수행함으로써',
#  '농업·농촌',
#  '발전에',
#  '기여해온',
#  '자랑스러운',
#  '농업인의',
#  '협동조합',
#  '금융그룹이다.',
#  '2.',
#  '우리는',
#  '이러한',
#  '긍지와',
#  '자부심을',
#  '가지고',
#  '윤리경영과',
#  '준법경영을',
#  '통해',
#  '농업인·고객의',
#  '사랑과',
#  '신뢰를',
#  '받는',
#  '아시아를',
#  '대표하는',
#  '글로벌',
#  '협동조합',
#  '금융그룹이',
#  '되고자',
#  '한다.',
#  '3.',
#  '이에',
#  '우리는',
#  '창의적',
#  '사고와',
#  '도전적',
#  '정신으로',
#  '우리의',
#  '사명을',
#  '달성하고',
#  '높은',
#  '윤리적',
#  '가치관을',
#  '바탕으로',
#  '정직하고',
#  '공정한',
#  '자세로',
#  '업무를',
#  '처리하며',
#  '부패방지와',
#  '깨끗한',
#  '직장풍토',
#  '조성을',
#  '위해',
#  '노력한다.',
#  '4.',
#  '우리는',
#  '농업인·고객에게',
#  '최고의',
#  '상품과',
#  '서비스를',
#  '제공하며',
#  '농업인·고객',
#  '만족과',
#  '새로운',
#  '가치창조의',
#  '경영을',
#  '통하여',
#  '농업인·고객',
#  '제일주의를',
#  '실천한다.',
#  '5.',
#  '우리는',
#  '국내법과',
#  '국제규정을',
#  '준수하고',
#  '자유경쟁의',
#  '시장질서를',
#  '존중하며,',
#  '모든',
#  '이해관계자와',
#  '상호',
#  '협력하는',
#  '공동체적인',
#  '관계를',
#  '구축하여',
#  '공동의',
#  '번영을',
#  '추구한다.',
#  '6.',
#  '7.',
#  '우리는',
#  '임직원',
#  '개개인의',
#  '인격을',
#  '존중하고',
#  '차별대우를',
#  '하지',
#  '않으며,',
#  '공평한',
#  '기회와',
#  '공정한',
#  '평가를',
#  '받도록',
#  '하는',
#  '한편',
#  '임직원의',
#  '건강과',
#  '삶의',
#  '질',
#  '향상을',
#  '위해',
#  '노력한다.',
#  '우리는',
#  '사회의',
#  '일부분으로서',
#  '공익활동에',
#  '적극적으로',
#  '참여하고,',
#  '끊임없이',
#  '새로운',
#  '가치를',
#  '창조하여',
#  '국가와',
#  '사회의',
#  '발전에',
#  '공헌한다.',
#  '8.',
#  '우리는',
#  '생명을',
#  '존중하고',
#  '자연과',
#  '환경보호',
#  '활동에',
#  '앞장서서',
#  '자연환경을',
#  '후세에',
#  '전하도록',
#  '최선을',
#  '다한다.',
#  '\x0c']
